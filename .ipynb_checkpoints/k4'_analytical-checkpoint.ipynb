# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import networkx as nx
import scipy.linalg

from steinberg import *

plt.rc("text", usetex=False)
plt.rc("font", family = "serif",size=14)
plt.rc("figure",figsize=(12,10))
# %config InlineBackend.figure_format = 'retina'

# %%
def eq_params_k4_2cycle():
    """
    Samples equilibrium parameter sets for a 4-state 2-cycle graph
    (k12, k23, k34, k41) and (k21, k32, k43, k14), ensuring zero cycle affinity.

    Returns
    -------
    labels_f : list of 4 floats
        Forward rates: [[k12, k24, k41], [k23, k34, k42]]
    labels_r : list of 4 floats
        Reverse rates: [[k21, k42, k14], [k32, k43, k24]]
    """

    # Sample 8 of the 10 parameters freely
    k24 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k41 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k21 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k14 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    
    k23 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k42 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k32 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k43 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    
    # Back-calculate k12
    
    k12 = (k21*k42*k14)/(k24 * k41)
    
    # Back-calculate k34
    
    k34 = (k32*k43*k24)/(k23*k42)

    labels_f = [[k12, k24, k41], [k23, k34, k42]]
    labels_r = [[k21, k42, k14], [k32, k43, k24]]

    return labels_f, labels_r

def params_shuffle_k4_2cycle(params):
    """
    Takes randomly sampled parameters from random_parameters(num_params) and converts to labels_f and labels_r strcuture
    """
    k12 = params[0]
    k23 = params[1]
    k34 = params[2]
    k41 = params[3]

    k21 = params[4]
    k32 = params[5]
    k43 = params[6]
    k14 = params[7]

    k24 = params[8]
    k42 = params[9]

    labels_f = [[k12, k24, k41], [k23, k34, k42]]
    labels_r = [[k21, k42, k14], [k32, k43, k24]]

    return labels_f, labels_r


def lap_k4_2cycle(labels_f, labels_r):
    # labels_f = [[k12, k24, k41], [k23, k34, k42]]
    k12 = labels_f[0][0]
    k24 = labels_f[0][1]
    k41 = labels_f[0][2]
    
    k23 = labels_f[1][0]
    k34 = labels_f[1][1]
    k42 = labels_f[1][2]
    
    # labels_r = [[k21, k42, k14], [k32, k43, k24]]
    
    k21 = labels_r[0][0]
    k14 = labels_r[0][2]
    k32 = labels_r[1][0]
    k43 = labels_r[1][1]
    
    lap = np.array([[-k14-k12, k21, 0, k41], [k12, -k21-k23-k24, k32, k42], [0, k23, -k32-k34, k43], [k14, k24, k34, -k41-k43-k42]],dtype=float)
    
    return lap

# %% [markdown]
# Next, we perform a few sanity checks to make sure the code is working as it should. First, we check that the area is actually zero when the affinity is zero?

# %%
labels_f, labels_r = eq_params_k4_2cycle()
lap = lap_k4_2cycle(labels_f, labels_r)
signal = make_observable([1,2,3,4])
is_zero_at_eq(lap,signal)
# Out:
# True

# %% [markdown]
# Are the eigenvalues/eigenvectors correct? Confirm $w_i \mathcal{L}(G) = \lambda_i w_i$ and  $\mathcal{L}(G) z_i = \lambda_i z_i$.

# %%
lambdas, w_i, z_i = spectrum_any(lap)

# %%
lambdas
# Out:
# array([-8.60430808e+01+0.j, -1.50027687e+01+0.j, -3.89626939e-01+0.j,
#        -4.90597214e-15+0.j])

# %%
w_i
# Out:
# array([[-6.09076786e-07, -2.66160417e-03,  9.99996456e-01,
#          5.68224726e-05],
#        [-7.04638071e-02, -1.74279972e-02, -1.96165505e-02,
#          9.97169147e-01],
#        [-4.76997617e-01,  5.85607944e-01,  5.87201745e-01,
#         -2.91085417e-01],
#        [ 5.00000000e-01,  5.00000000e-01,  5.00000000e-01,
#          5.00000000e-01]])

# %%
z_i
# Out:
# array([[-1.89469669e-04, -6.30718372e-01, -6.89388123e-01,
#          7.58517714e-01],
#        [-7.07767884e-01, -1.33351097e-01,  7.23492911e-01,
#          6.48403665e-01],
#        [ 7.06443412e-01, -3.98752380e-04,  1.92728612e-03,
#          1.72257046e-03],
#        [ 1.51394119e-03,  7.64468221e-01, -3.60320741e-02,
#          6.49661236e-02]])

# %%
print(lambdas[0]*w_i[0,:])
# Out:
# [ 5.24068431e-05-0.j  2.29012623e-01-0.j -8.60427759e+01+0.j
#  -4.88918060e-03+0.j]

# %%
print(w_i[0,:]@lap)
# Out:
# [ 5.24068431e-05  2.29012623e-01 -8.60427759e+01 -4.88918060e-03]

# %%
print(lambdas[0]*z_i[:,0])
# Out:
# [ 1.63025541e-02-0.j  6.08985292e+01-0.j -6.07845676e+01+0.j
#  -1.30264164e-01+0.j]

# %%
print(lap@z_i[:,0])
# Out:
# [ 1.63025541e-02  6.08985292e+01 -6.07845676e+01 -1.30264164e-01]

# %% [markdown]
# Does $\sum_{k=1}^N L^{(k)} = I$?

# %%
check_Lk(lap)
# Out:
# True

# %%
labels_f_eq, labels_r_eq = eq_params_k4_2cycle()
lap_eq = lap_k4_2cycle(labels_f_eq, labels_r_eq)
lambdas, w_i, z_i = spectrum_any(lap_eq)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap_eq))
delta_u_star = np.diag(pi)
B_eq = B_matrix(lambdas, Lk_list, delta_u_star)
print(f"B symmetric at equilibrium: {check_symmetric(B_eq)}")
# Out:
# B symmetric at equilibrium: True

# %% [markdown]
# Does the numerical area agree with the analytical area?

# %%
labels_f, labels_r = eq_params_k4_2cycle()
lap_eq = lap_k4_2cycle(labels_f, labels_r)
aff = cycle_affinity(labels_f,labels_r)
print(f"Affinity at equilibrium: {aff:.2e}  (should be ~0)")

signal = make_observable([1,2,3,4])
tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
check_analytical_numerical_consistency(signal, lap_eq, tau)
print("PASS: analytical and numerical areas agree at equilibrium")

params_neq = random_parameters(num_params=10)
labels_f, labels_r = params_shuffle_k4_2cycle(params_neq)
lap_neq = lap_k4_2cycle(labels_f, labels_r)
aff_neq = cycle_affinity(labels_f, labels_r)
print(f"\nAffinity off equilibrium: {aff_neq:.4f}")

tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
a_13, a_31 = asymmetric_autocorrelation(signal, lap_neq, tau_neq)
print(f"tau_max: {tau_neq[-1]:.4f}")
print(f"a_13 at tau_max: {a_13[-1]:.6e}")
print(f"a_31 at tau_max: {a_31[-1]:.6e}")

tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
check_analytical_numerical_consistency(signal, lap_neq, tau_neq)
print("PASS: analytical and numerical areas agree off equilibrium")
# Out:
# Affinity at equilibrium: 2.22e-16  (should be ~0)
# PASS: analytical and numerical areas agree at equilibrium
#
# Affinity off equilibrium: 1.0126
# tau_max: 45.6925
# a_13 at tau_max: 8.203439e+01
# a_31 at tau_max: 8.203439e+01
# PASS: analytical and numerical areas agree off equilibrium

# %% [markdown]
# Check that the autocorrelation functions are well behaved

# %%
plt.plot(tau, a_13, label='a_13')
plt.plot(tau, a_31, label='a_31')
plt.legend()
plt.show()

# %% [markdown]
# # Parameter set 3

# %% [markdown]
# {(1, 2): 0.00497, (1, 4): 8.928, (2, 1): 0.1793, (2, 3): 187459.0470622625, (2, 4): 11.94, (3, 4): 12.44, (3, 2): 537.1, (4, 1): 0.088723288231904, (4, 3): 1.196, (4, 2): 0.003289}
#
#     labels_f : list of 4 floats
#         Forward rates: [[k12, k24, k41], [k23, k34, k42]]
#     labels_r : list of 4 floats
#         Reverse rates: [[k21, k42, k14], [k32, k43, k24]]

# %%
k12 = 0.00497
k34 = 12.44

k21 = 0.1793
k32 = 537.1
k43 = 1.196
k14 = 8.928

k42 = 0.003289
k24 = 11.94

k23 = (k24 * k43 * k32) / (k34 * k42)

k41 = (k42 * k21 * k14) / (k12 * k24)

labels_f = [[k12, k24, k41], [k23, k34, k42]]
labels_r = [[k21, k42, k14], [k32, k43, k24]]

aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
print(aff_c1,aff_c2)
# Out:
# 0.0 1.1102230246251565e-16

# %%
print(labels_f)
print(labels_r)
# Out:
# [[0.00497, 11.94, 0.088723288231904], [187459.04706226249, 12.44, 0.003289]]
# [[0.1793, 0.003289, 8.928], [537.1, 1.196, 11.94]]

# %%
lap = lap_k4_2cycle(labels_f,labels_r)
print(lap)
# Out:
# [[-8.93297000e+00  1.79300000e-01  0.00000000e+00  8.87232882e-02]
#  [ 4.97000000e-03 -1.87471166e+05  5.37100000e+02  3.28900000e-03]
#  [ 0.00000000e+00  1.87459047e+05 -5.49540000e+02  1.19600000e+00]
#  [ 8.92800000e+00  1.19400000e+01  1.24400000e+01 -1.28801229e+00]]

# %%
# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# [-1.88008267e+05+0.j -1.36610810e+01+0.j -8.99898509e+00+0.j
#  -3.50563128e-13+0.j]

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

# %%
N = 2000
affinities_c1 = np.empty(N, dtype=float)
affinities_c2 = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)

# perturb edge k21
cycle_idx = 0
edge_idx = 0
perturb_edge = labels_r[cycle_idx][edge_idx]
perturb_edge
# Out:
# 0.1793

# %%
for i in tqdm(range(0,N)):
    
    labels_r[cycle_idx][edge_idx] = perturb_edge
    
    lap = lap_k4_2cycle(labels_f, labels_r)
    
    aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
    aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
    affinities_c1[i] = aff_c1
    affinities_c2[i] = aff_c2

    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)
    eigvals_all_r[i, :] = np.sort(lambdas.real)
    eigvals_all_c[i, :] = np.sort(lambdas.imag)
    
    perturb_edge *= 1.01

lambdas, w_i, z_i = spectrum_any(lap)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap))
delta_u_star = np.diag(pi)
B_final = B_matrix(lambdas, Lk_list, delta_u_star)
print("B(G) at final step:")
print(B_final)
check_symmetric(B_final, rtol=1e-05, atol=1e-08)
# Out:
# 100%|███████████████████████████████████████| 2000/2000 [00:42<00:00, 47.45it/s]
# B(G) at final step:
# [[-1.06054536e-02+0.j -1.12932484e-09+0.j -1.59139874e-04+0.j
#    1.07645946e-02+0.j]
#  [ 1.61330563e-10+0.j -1.51477213e-16+0.j -2.14356163e-11+0.j
#   -1.39894795e-10+0.j]
#  [ 2.35140180e-05+0.j  2.44649342e-12+0.j -3.11934496e-06+0.j
#   -2.03946755e-05+0.j]
#  [ 1.05819395e-02+0.j  1.12687850e-09+0.j  1.62259241e-04+0.j
#   -1.07441998e-02+0.j]]
# False

# %%
# Steinberg curve plot
plt.plot(np.abs(affinities_c1),analytical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities_c1),numerical_areas,linewidth=1, color= 'blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 3, Figure 4D")
plt.legend()
plt.savefig("pset3_fig4d.png")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
#plt.savefig(f"eigenvalue_evolution_edge_{edge_idx}.png", dpi=300)
plt.show()

# %% [markdown]
# This is much better, I think.

# %% [markdown]
# # Random parameter sets

# %%
labels_f = [[839.2984685322933, 2.546, 0.002038], [0.8417, 0.11410436849606644, 0.4205]]
labels_r = [[538.0, 0.4205, 0.01925], [0.4239, 0.03742, 2.546]]

print(labels_f)
print(labels_r)
# Out:
# [[839.2984685322933, 2.546, 0.002038], [0.8417, 0.11410436849606644, 0.4205]]
# [[538.0, 0.4205, 0.01925], [0.4239, 0.03742, 2.546]]

# %%
aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
print(aff_c1,aff_c2)
# Out:
# 0.0 0.0

# %%
lap = lap_k4_2cycle(labels_f,labels_r)
print(lap)
# Out:
# [[-8.39317719e+02  5.38000000e+02  0.00000000e+00  2.03800000e-03]
#  [ 8.39298469e+02 -5.41387700e+02  4.23900000e-01  4.20500000e-01]
#  [ 0.00000000e+00  8.41700000e-01 -5.38004368e-01  3.74200000e-02]
#  [ 1.92500000e-02  2.54600000e+00  1.14104368e-01 -4.59958000e-01]]

# %%
# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# [-1.37863586e+03+0.j -2.49242906e+00+0.j -5.75086943e-01+0.j
#   2.18182783e-14+0.j]

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

N = 2000
affinities_c1 = np.empty(N, dtype=float)
affinities_c2 = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)

# perturb edge k21
cycle_idx = 0
edge_idx = 0
perturb_edge = labels_r[cycle_idx][edge_idx]
perturb_edge

for i in tqdm(range(0,N)):
    
    labels_r[cycle_idx][edge_idx] = perturb_edge
    
    lap = lap_k4_2cycle(labels_f, labels_r)
    
    aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
    aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
    affinities_c1[i] = aff_c1
    affinities_c2[i] = aff_c2
    
    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)
    eigvals_all_r[i, :] = np.sort(lambdas.real)
    eigvals_all_c[i, :] = np.sort(lambdas.imag)
    
    perturb_edge *= 1.01
# Out:
# 100%|███████████████████████████████████████| 2000/2000 [00:56<00:00, 35.60it/s]

# %%
lambdas, w_i, z_i = spectrum_any(lap)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap))
delta_u_star = np.diag(pi)
B_final = B_matrix(lambdas, Lk_list, delta_u_star)
print("B(G) at final step:")
print(B_final)
check_symmetric(B_final, rtol=1e-05, atol=1e-08)
# Out:
# B(G) at final step:
# [[-9.42796552e-02+0.j -3.38170613e-10+0.j  6.11685363e-03+0.j
#    8.81628019e-02+0.j]
#  [-3.37993310e-10+0.j -1.22700538e-18+0.j  2.19289018e-11+0.j
#    3.16064410e-10+0.j]
#  [ 1.08398700e-02+0.j  3.88814054e-11+0.j -5.30715290e-03+0.j
#   -5.53271718e-03+0.j]
#  [ 8.34397855e-02+0.j  2.99289209e-10+0.j -8.09700750e-04+0.j
#   -8.26300851e-02+0.j]]
# False

# %%
# Steinberg curve plot
plt.plot(np.abs(affinities_c1),analytical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities_c1),numerical_areas,linewidth=1, color= 'blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 4, Figure 4D")
plt.legend()
plt.savefig("pset4_fig4d.png")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
#plt.savefig(f"eigenvalue_evolution_edge_{edge_idx}.png", dpi=300)
plt.show()

# %%
labels_f = [[2.635390337429404, 0.134, 37.58], [0.4503, 0.002141670617978357, 24.85]]
labels_r = [[0.1562, 24.85, 3.419], [0.002601, 68.76, 0.134]]

print(labels_f)
print(labels_r)
# Out:
# [[2.635390337429404, 0.134, 37.58], [0.4503, 0.002141670617978357, 24.85]]
# [[0.1562, 24.85, 3.419], [0.002601, 68.76, 0.134]]

# %%
aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
print(aff_c1,aff_c2)
# Out:
# 1.1102230246251565e-16 0.0

# %%
lap = lap_k4_2cycle(labels_f,labels_r)
print(lap)
# Out:
# [[-6.05439034e+00  1.56200000e-01  0.00000000e+00  3.75800000e+01]
#  [ 2.63539034e+00 -7.40500000e-01  2.60100000e-03  2.48500000e+01]
#  [ 0.00000000e+00  4.50300000e-01 -4.74267062e-03  6.87600000e+01]
#  [ 3.41900000e+00  1.34000000e-01  2.14167062e-03 -1.31190000e+02]]

# %%
# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# [-1.32233147e+02+0.j -5.18024912e+00+0.j -5.76237227e-01+0.j
#  -1.09192647e-16+0.j]

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

N = 2000
affinities_c1 = np.empty(N, dtype=float)
affinities_c2 = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)

# perturb edge k21
cycle_idx = 0
edge_idx = 0
perturb_edge = labels_r[cycle_idx][edge_idx]
perturb_edge

for i in tqdm(range(0,N)):
    
    labels_r[cycle_idx][edge_idx] = perturb_edge
    
    lap = lap_k4_2cycle(labels_f, labels_r)
    
    aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
    aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
    affinities_c1[i] = aff_c1
    affinities_c2[i] = aff_c2
    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))
    
    lambdas, w_i, z_i = spectrum_any(lap)
    eigvals_all_r[i, :] = np.sort(lambdas.real)
    eigvals_all_c[i, :] = np.sort(lambdas.imag)
    
    perturb_edge *= 1.01
# Out:
#  90%|██████████████████████████████████▉    | 1792/2000 [00:33<00:04, 42.79it/s]

# %%
# Steinberg curve plot
plt.plot(np.abs(affinities_c1),analytical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities_c1),numerical_areas,linewidth=1, color= 'blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 5, Figure 4D")
plt.legend()
plt.savefig("pset5_fig4d.png")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
#plt.savefig(f"eigenvalue_evolution_edge_{edge_idx}.png", dpi=300)
plt.show()

# %%
labels_f, labels_r = eq_params_k4_2cycle()
print(labels_f)
print(labels_r)
# Out:
# [[0.0003198327573927035, 0.008684, 0.02724], [460.7, 0.03588959409594097, 0.00104]]
# [[0.003252, 0.00104, 0.02237], [154.7, 0.0128, 0.008684]]

# %%
aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
print(aff_c1,aff_c2)
# Out:
# 2.2204460492503128e-16

# %%
lap = lap_k4_2cycle(labels_f,labels_r)
print(lap)
# Out:
# [[-2.26898328e-02  3.25200000e-03  0.00000000e+00  2.72400000e-02]
#  [ 3.19832757e-04 -4.60711936e+02  1.54700000e+02  1.04000000e-03]
#  [ 0.00000000e+00  4.60700000e+02 -1.54735890e+02  1.28000000e-02]
#  [ 2.23700000e-02  8.68400000e-03  3.58895941e-02 -4.10800000e-02]]

# %%
# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# [-6.15417958e+02+0.j -6.59737695e-02+0.j -2.76638892e-02+0.j
#  -3.26928490e-14+0.j]

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

N = 2000
affinities_c1 = np.empty(N, dtype=float)
affinities_c2 = np.empty(N, dtype=float)
areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)

# perturb edge k21
cycle_idx = 0
edge_idx = 0
perturb_edge = labels_r[cycle_idx][edge_idx]
perturb_edge

for i in tqdm(range(0,N)):
    
    labels_r[cycle_idx][edge_idx] = perturb_edge
    
    lap = lap_k4_2cycle(labels_f, labels_r)
    
    aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
    aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
    affinities_c1[i] = aff_c1
    affinities_c2[i] = aff_c2
    
    areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)
    eigvals_all_r[i, :] = np.sort(lambdas.real)
    eigvals_all_c[i, :] = np.sort(lambdas.imag)
    
    perturb_edge *= 1.01
# Out:
# 100%|█████████████████████████████████████| 2000/2000 [00:00<00:00, 9585.57it/s]

# %%
# Steinberg curve plot
plt.plot(np.abs(affinities_c1),analytical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities_c1),numerical_areas,linewidth=1, color= 'blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 6, Figure 4D")
plt.legend()
plt.savefig("pset6_fig4d.png")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
#plt.savefig(f"eigenvalue_evolution_edge_{edge_idx}.png", dpi=300)
plt.show()
