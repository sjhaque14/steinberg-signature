# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import networkx as nx
import scipy.linalg

from steinberg import *

plt.rc("text", usetex=False)
plt.rc("font", family = "serif",size=14)
plt.rc("figure",figsize=(12,10))
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## K4' specific functions

# %%
def eq_params_k4_2cycle():
    """
    Samples equilibrium parameter sets for a 4-state 2-cycle graph
    [[k21, k42, k14], [k32, k43, k24]] and [[k12, k24, k41], [k23, k34, k42]], ensuring zero cycle affinity.

    Returns
    -------
    labels_f : list of 4 floats
        Forward rates: [[k21, k42, k14], [k32, k43, k24]]
    labels_r : list of 4 floats
        Reverse rates: [[k12, k24, k41], [k23, k34, k42]]
    """

    # Sample 8 of the 10 parameters freely
    k24 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k41 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k21 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k14 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    
    k23 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k42 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k32 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k43 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    
    # Back-calculate k12
    
    k12 = (k21*k42*k14)/(k24 * k41)
    
    # Back-calculate k34
    
    k34 = (k32*k43*k24)/(k23*k42)

    labels_f = [[k21, k42, k14], [k32, k43, k24]]   # forward: 1->2->4->1, 2->3->4->2
    labels_r = [[k12, k24, k41], [k23, k34, k42]]   # reverse traversals

    return labels_f, labels_r

def params_shuffle_k4_2cycle(params):
    """
    Takes randomly sampled parameters from random_parameters(num_params) and converts to labels_f and labels_r strcuture
    """
    k12 = params[0]
    k23 = params[1]
    k34 = params[2]
    k41 = params[3]

    k21 = params[4]
    k32 = params[5]
    k43 = params[6]
    k14 = params[7]

    k24 = params[8]
    k42 = params[9]

    labels_f = [[k21, k42, k14], [k32, k43, k24]]   # forward: 1->2->4->1, 2->3->4->2
    labels_r = [[k12, k24, k41], [k23, k34, k42]]   # reverse traversals

    return labels_f, labels_r


def lap_k4_2cycle(labels_f, labels_r):
    """
    Column-based Laplacian for the 4-vertex 2-cycle graph K_4'.

    Convention (Fig. 1C): k_ij = l(j -> i), so L[i,j] = k_ij for i != j
    and L[i,i] = -sum_k l(i -> k).

    labels_f : [[k21, k42, k14], [k32, k43, k24]]   forward traversals
    labels_r : [[k12, k24, k41], [k23, k34, k42]]   reverse traversals
    """
    k21, k42, k14 = labels_f[0]
    k32, k43, k24 = labels_f[1]
    k12, _,   k41 = labels_r[0]     # labels_r[0][1] is k24, already bound
    k23, k34, _   = labels_r[1]     # labels_r[1][2] is k42, already bound

    assert np.isclose(labels_f[0][1], labels_r[1][2]), "k42 desynced between cycles"
    assert np.isclose(labels_f[1][2], labels_r[0][1]), "k24 desynced between cycles"

    return np.array([
        [-(k21 + k41),  k12,                  0,            k14                ],
        [  k21,        -(k12 + k32 + k42),    k23,          k24                ],
        [  0,           k32,                 -(k23 + k43),  k34                ],
        [  k41,         k42,                  k43,         -(k14 + k24 + k34) ]], dtype=float)

# %% [markdown]
# ## Code sanity checks

# %% [markdown]
# Next, we perform a few sanity checks to make sure the code is working as it should. First, we check that the area is actually zero when the affinity is zero?

# %%
labels_f, labels_r = eq_params_k4_2cycle()
lap = lap_k4_2cycle(labels_f, labels_r)
signal = make_observable([1,2,3,4])
is_zero_at_eq(lap,signal)
# Out:
# True

# %% [markdown]
# Are the eigenvalues/eigenvectors correct? Confirm $w_i \mathcal{L}(G) = \lambda_i w_i$ and  $\mathcal{L}(G) z_i = \lambda_i z_i$. The last two lines in this cell should be the same array.

# %%
lambdas, w_i, z_i = spectrum_any(lap)

print(lambdas)
print("--------")
print(w_i)
print("--------")
print(z_i)
print("--------")
print(lambdas[0]*w_i[0,:])
print("--------")
print(w_i[0,:]@lap)
print("--------")
print(lambdas[0]*z_i[:,0])
print("--------")
print(lap@z_i[:,0])
# Out:
# [-1.54474857e+02+0.j -1.36181788e+01+0.j -1.14514293e+01+0.j
#   1.46284782e-17+0.j]
# --------
# [[ 9.99999991e-01 -1.29471879e-04  1.23285862e-05 -3.94309524e-05]
#  [ 4.92622670e-06  1.39006555e-02 -9.99903381e-01 -1.69654906e-06]
#  [ 4.72703803e-05  1.45857798e-01  9.89305565e-01 -2.11703274e-05]
#  [-5.00000000e-01 -5.00000000e-01 -5.00000000e-01 -5.00000000e-01]]
# --------
# [[ 7.07272823e-01  7.38574222e-05  6.27138773e-05 -3.94494814e-05]
#  [-3.32264598e-04  7.56200007e-01  7.02143458e-01 -1.43140637e-04]
#  [ 6.48562889e-08 -1.11503791e-01  9.76240572e-03 -2.93422318e-07]
#  [-7.06940623e-01 -6.44770074e-01 -7.11968578e-01 -9.99999989e-01]]
# --------
# [-1.54474856e+02+0.j  2.00001499e-02-0.j -1.90445659e-03+0.j
#   6.09109074e-03-0.j]
# --------
# [-1.54474856e+02  2.00001499e-02 -1.90445659e-03  6.09109074e-03]
# --------
# [-1.09255868e+02+0.j  5.13265262e-02-0.j -1.00186660e-05+0.j
#   1.09204552e+02-0.j]
# --------
# [-1.09255868e+02  5.13265262e-02 -1.00186660e-05  1.09204552e+02]

# %% [markdown]
# Does $\sum_{k=1}^N L^{(k)} = I$?

# %%
check_Lk(lap)
# Out:
# True

# %% [markdown]
# Is B(G) symmetric at equilibrium?

# %%
labels_f_eq, labels_r_eq = eq_params_k4_2cycle()
lap_eq = lap_k4_2cycle(labels_f_eq, labels_r_eq)
lambdas, w_i, z_i = spectrum_any(lap_eq)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap_eq))
delta_u_star = np.diag(pi)
B_eq = B_matrix(lambdas, Lk_list, delta_u_star)
print(f"B symmetric at equilibrium: {check_symmetric(B_eq)}")
# Out:
# B symmetric at equilibrium: True

# %% [markdown]
# Does the numerical area agree with the analytical area?

# %%
labels_f, labels_r = eq_params_k4_2cycle()
lap_eq = lap_k4_2cycle(labels_f, labels_r)
aff = cycle_affinity(labels_f,labels_r)
print(f"Affinity at equilibrium: {aff:.2e}  (should be ~0)")

signal = make_observable([1,2,3,4])
tau,tau_max = define_tau_range(lap_eq, max_points=500, cap_factor=10.0, tau_cap=1000.0)
check_analytical_numerical_consistency(signal, lap_eq, tau)
print("PASS: analytical and numerical areas agree at equilibrium")

params_neq = random_parameters(num_params=10)
labels_f, labels_r = params_shuffle_k4_2cycle(params_neq)
lap_neq = lap_k4_2cycle(labels_f, labels_r)
aff_neq = cycle_affinity(labels_f, labels_r)
print(f"\nAffinity off equilibrium: {aff_neq:.4f}")

tau,tau_max = define_tau_range(lap_neq, max_points=500, cap_factor=10.0, tau_cap=1000.0)
a_13, a_31 = asymmetric_autocorrelation(signal, lap_neq, tau)
print(f"tau_max: {tau[-1]:.4f}")
print(f"a_13 at tau_max: {a_13[-1]:.6e}")
print(f"a_31 at tau_max: {a_31[-1]:.6e}")

tau,tau_max = define_tau_range(lap_neq, max_points=500, cap_factor=10.0, tau_cap=1000.0)
check_analytical_numerical_consistency(signal, lap_neq, tau)
print("PASS: analytical and numerical areas agree off equilibrium")
# Out:
# Affinity at equilibrium: 2.22e-16  (should be ~0)
# PASS: analytical and numerical areas agree at equilibrium
#
# Affinity off equilibrium: 0.4166
# tau_max: 0.4000
# a_13 at tau_max: 2.220942e+03
# a_31 at tau_max: 2.220942e+03
# PASS: analytical and numerical areas agree off equilibrium

# %% [markdown]
# Check that the autocorrelation functions are well behaved

# %%
plt.plot(tau, a_13, label='a_13')
plt.plot(tau, a_31, label='a_31')
plt.legend()
plt.show()

# %%
lambdas, w_i, z_i = spectrum_any(lap_neq)

print(lambdas)
# Out:
# [-1.65377698e+02+0.j -9.68333975e+01+0.j -2.50010335e+01+0.j
#   2.94349328e-15+0.j]

# %% [markdown]
# # Parameter sets for Figure 4

# %% [markdown]
# ## Parameter set 1

# %%
seed = np.random.randint(0, 2**32 - 1)
print(f"seed = {2780282839}")
np.random.seed(2780282839)

labels_f, labels_r = eq_params_k4_2cycle()

print(labels_f)
print(labels_r)

aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
print(aff_c1,aff_c2)

lap = lap_k4_2cycle(labels_f,labels_r)
print(lap)

# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# seed = 2780282839
# [[7.494, 0.08107, 0.008381], [0.002349, 0.00226, 0.002358]]
# [[0.05869432518309337, 0.002358, 36.79], [0.006282, 2.4579732467926295e-05, 0.08107]]
# 0.0 2.2204460492503128e-16
# [[-4.42840000e+01  5.86943252e-02  0.00000000e+00  8.38100000e-03]
#  [ 7.49400000e+00 -1.42113325e-01  6.28200000e-03  2.35800000e-03]
#  [ 0.00000000e+00  2.34900000e-03 -8.54200000e-03  2.45797325e-05]
#  [ 3.67900000e+01  8.10700000e-02  2.26000000e-03 -1.07635797e-02]]
# [-4.43009173e+01+0.j -1.35980735e-01+0.j -8.52086453e-03+0.j
#   1.38676680e-17+0.j]

# %%
print(round_sig(0.05869432518309337))
print(round_sig(2.4579732467926295e-05))
# Out:
# 0.05869
# 2.458e-05

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

N = 2000
affinities_c1 = np.empty(N, dtype=float)
affinities_c2 = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)
complex_steps = []

# perturb edge k21
cycle_idx = 0
edge_idx = 0
perturb_edge = labels_f[cycle_idx][edge_idx]
perturb_edge

for i in tqdm(range(0,N)):

    # make sure you perturb the correct rate in the correct data structure
    labels_f[cycle_idx][edge_idx] = perturb_edge
    
    lap = lap_k4_2cycle(labels_f, labels_r)
    
    aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
    aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
    affinities_c1[i] = aff_c1
    affinities_c2[i] = aff_c2

    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)

    order = np.lexsort((lambdas.imag, lambdas.real))
    eigvals_all_r[i, :] = lambdas.real[order]
    eigvals_all_c[i, :] = lambdas.imag[order]

    # check that the zero eigenvalue doesn't turn complex
    zero_idx = np.argmin(np.abs(lambdas))
    assert abs(lambdas.imag[zero_idx]) < 1e-12, f"zero eigenvalue went complex at step {i}"
    if np.abs(lambdas.imag).max() > 1e-9:
        complex_steps.append(i)
    
    perturb_edge *= 1.01

lambdas, w_i, z_i = spectrum_any(lap)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap))
delta_u_star = np.diag(pi)
B_final = B_matrix(lambdas, Lk_list, delta_u_star)
print("B(G) at final step:")
print(B_final)
check_symmetric(B_final, rtol=1e-05, atol=1e-08)
# Out:
#   1%|▎                                        | 18/2000 [00:00<00:34, 56.97it/s]
# warning: tau_max 1173.6 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.6 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.5 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.5 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.5 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.5 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.4 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.4 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.4 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.3 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.3 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.3 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.3 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.2 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.2 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.2 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.1 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.1 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
#   2%|▌                                        | 30/2000 [00:00<00:33, 58.39it/s]
# warning: tau_max 1173.1 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.1 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.0 exceeds cap 1000.0 (spectral gap 8.52e-03); integral will be truncated
# warning: tau_max 1173.0 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1173.0 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.9 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.9 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.9 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.8 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.8 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.8 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.7 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.7 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.7 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.7 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.6 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.6 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.6 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
#   3%|█                                        | 54/2000 [00:00<00:33, 58.83it/s]
# warning: tau_max 1172.5 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.5 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.5 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.4 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.4 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.3 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.3 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.3 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.2 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.2 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.2 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.1 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.1 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.1 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.0 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1172.0 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1171.9 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1171.9 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
#   3%|█▎                                       | 66/2000 [00:01<00:32, 59.14it/s]
# warning: tau_max 1171.9 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1171.8 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1171.8 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1171.8 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1171.7 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1171.7 exceeds cap 1000.0 (spectral gap 8.53e-03); integral will be truncated
# warning: tau_max 1171.6 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1171.6 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1171.6 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1171.5 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1171.5 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1171.4 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1171.4 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1171.4 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1171.3 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1171.3 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1171.2 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1171.2 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
#   4%|█▋                                       | 84/2000 [00:01<00:32, 59.20it/s]
# warning: tau_max 1171.2 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1171.1 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1171.1 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1171.0 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1171.0 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1170.9 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1170.9 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1170.9 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1170.8 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1170.8 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1170.7 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1170.7 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1170.6 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1170.6 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1170.5 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1170.5 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1170.4 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1170.4 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
#   5%|██                                      | 102/2000 [00:01<00:32, 59.24it/s]
# warning: tau_max 1170.4 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1170.3 exceeds cap 1000.0 (spectral gap 8.54e-03); integral will be truncated
# warning: tau_max 1170.3 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1170.2 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1170.2 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1170.1 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1170.1 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1170.0 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1170.0 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.9 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.9 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.8 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.8 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
#   6%|██▎                                     | 114/2000 [00:01<00:32, 58.09it/s]
# warning: tau_max 1169.7 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.7 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.6 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.6 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.5 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.5 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.4 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.4 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.3 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.3 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.2 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.2 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.1 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.1 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
#   7%|██▋                                     | 132/2000 [00:02<00:31, 59.02it/s]
# warning: tau_max 1169.0 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1169.0 exceeds cap 1000.0 (spectral gap 8.55e-03); integral will be truncated
# warning: tau_max 1168.9 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.8 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.8 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.7 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.7 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.6 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.6 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.5 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.5 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.4 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.4 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.3 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.2 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.2 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.1 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.1 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
#   8%|███                                     | 156/2000 [00:02<00:31, 59.27it/s]
# warning: tau_max 1168.0 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1168.0 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1167.9 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1167.9 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1167.8 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1167.7 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1167.7 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1167.6 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1167.6 exceeds cap 1000.0 (spectral gap 8.56e-03); integral will be truncated
# warning: tau_max 1167.5 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1167.5 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1167.4 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1167.3 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1167.3 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1167.2 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1167.2 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1167.1 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1167.0 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1167.0 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1166.9 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1166.9 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
#   8%|███▎                                    | 168/2000 [00:02<00:30, 59.16it/s]
# warning: tau_max 1166.8 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1166.7 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1166.7 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1166.6 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1166.6 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1166.5 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1166.4 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1166.4 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1166.3 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1166.3 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1166.2 exceeds cap 1000.0 (spectral gap 8.57e-03); integral will be truncated
# warning: tau_max 1166.1 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1166.1 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1166.0 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1166.0 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1165.9 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1165.8 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1165.8 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
#   9%|███▋                                    | 186/2000 [00:03<00:30, 59.13it/s]
# warning: tau_max 1165.7 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1165.6 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1165.6 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1165.5 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1165.5 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1165.4 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1165.3 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1165.3 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1165.2 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1165.1 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1165.1 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1165.0 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1165.0 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1164.9 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1164.8 exceeds cap 1000.0 (spectral gap 8.58e-03); integral will be truncated
# warning: tau_max 1164.8 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1164.7 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1164.6 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
#  10%|████                                    | 204/2000 [00:03<00:30, 58.69it/s]
# warning: tau_max 1164.6 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1164.5 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1164.4 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1164.4 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1164.3 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1164.3 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1164.2 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1164.1 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1164.1 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1164.0 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1163.9 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1163.9 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1163.8 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1163.8 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1163.7 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1163.6 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1163.6 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
# warning: tau_max 1163.5 exceeds cap 1000.0 (spectral gap 8.59e-03); integral will be truncated
#  11%|████▍                                   | 222/2000 [00:03<00:31, 55.66it/s]
# warning: tau_max 1163.4 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1163.4 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1163.3 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1163.2 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1163.2 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1163.1 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1163.1 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1163.0 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1162.9 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1162.9 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1162.8 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1162.7 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1162.7 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1162.6 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1162.6 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1162.5 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1162.4 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1162.4 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
#  12%|████▉                                   | 246/2000 [00:04<00:32, 53.19it/s]
# warning: tau_max 1162.3 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1162.2 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1162.2 exceeds cap 1000.0 (spectral gap 8.60e-03); integral will be truncated
# warning: tau_max 1162.1 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1162.1 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1162.0 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1161.9 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1161.9 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1161.8 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1161.7 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1161.7 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1161.6 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1161.6 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1161.5 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1161.4 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1161.4 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1161.3 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1161.2 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
#  13%|█████▎                                  | 264/2000 [00:04<00:32, 53.67it/s]
# warning: tau_max 1161.2 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1161.1 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1161.1 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1161.0 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1160.9 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1160.9 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1160.8 exceeds cap 1000.0 (spectral gap 8.61e-03); integral will be truncated
# warning: tau_max 1160.8 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1160.7 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1160.6 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1160.6 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1160.5 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1160.5 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1160.4 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1160.4 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1160.3 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1160.2 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1160.2 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
#  14%|█████▌                                  | 276/2000 [00:04<00:31, 54.98it/s]
# warning: tau_max 1160.1 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1160.1 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1160.0 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1159.9 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1159.9 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1159.8 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1159.8 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1159.7 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1159.7 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1159.6 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1159.5 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1159.5 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1159.4 exceeds cap 1000.0 (spectral gap 8.62e-03); integral will be truncated
# warning: tau_max 1159.4 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1159.3 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1159.3 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1159.2 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1159.2 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
#  15%|█████▉                                  | 294/2000 [00:05<00:32, 53.01it/s]
# warning: tau_max 1159.1 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1159.0 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1159.0 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.9 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.9 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.8 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.8 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.7 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.7 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.6 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.6 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.5 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.5 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.4 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.4 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.3 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.2 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
#  16%|██████▏                                 | 312/2000 [00:05<00:32, 51.68it/s]
# warning: tau_max 1158.2 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.1 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.1 exceeds cap 1000.0 (spectral gap 8.63e-03); integral will be truncated
# warning: tau_max 1158.0 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1158.0 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.9 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.9 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.8 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.8 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.7 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.7 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.6 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.6 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
#  16%|██████▌                                 | 330/2000 [00:05<00:32, 51.94it/s]
# warning: tau_max 1157.6 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.5 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.5 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.4 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.4 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.3 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.3 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.2 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.2 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.1 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.1 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.0 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1157.0 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1156.9 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1156.9 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1156.9 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1156.8 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1156.8 exceeds cap 1000.0 (spectral gap 8.64e-03); integral will be truncated
# warning: tau_max 1156.7 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.7 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.6 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.6 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.5 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.5 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
#  18%|███████                                 | 354/2000 [00:06<00:31, 52.83it/s]
# warning: tau_max 1156.5 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.4 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.4 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.3 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.3 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.3 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.2 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.2 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.1 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.1 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.0 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.0 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1156.0 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1155.9 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1155.9 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1155.9 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1155.8 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1155.8 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
#  18%|███████▎                                | 366/2000 [00:06<00:30, 52.87it/s]
# warning: tau_max 1155.7 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1155.7 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1155.7 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1155.6 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1155.6 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1155.5 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1155.5 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1155.5 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1155.4 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1155.4 exceeds cap 1000.0 (spectral gap 8.65e-03); integral will be truncated
# warning: tau_max 1155.4 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1155.3 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1155.3 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1155.3 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1155.2 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1155.2 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1155.2 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1155.1 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
#  19%|███████▋                                | 384/2000 [00:06<00:30, 53.63it/s]
# warning: tau_max 1155.1 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1155.1 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1155.0 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1155.0 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1155.0 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.9 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.9 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.9 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.8 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.8 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.8 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.7 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.7 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.7 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.6 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.6 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.6 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.5 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
#  20%|████████                                | 402/2000 [00:07<00:29, 53.37it/s]
# warning: tau_max 1154.5 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.5 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.5 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.4 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.4 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.4 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.3 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.3 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.3 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.3 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.2 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.2 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.2 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.1 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.1 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.1 exceeds cap 1000.0 (spectral gap 8.66e-03); integral will be truncated
# warning: tau_max 1154.1 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1154.0 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
#  21%|████████▍                               | 420/2000 [00:07<00:29, 53.79it/s]
# warning: tau_max 1154.0 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1154.0 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1154.0 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.9 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.9 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.9 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.9 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.8 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.8 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.8 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.8 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.7 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.7 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.7 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.7 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.6 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.6 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.6 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
#  22%|████████▊                               | 438/2000 [00:07<00:29, 53.28it/s]
# warning: tau_max 1153.6 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.6 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.5 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.5 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.5 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.5 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.4 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.4 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.4 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.4 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.4 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.3 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
#  22%|█████████                               | 450/2000 [00:08<00:29, 52.90it/s]
# warning: tau_max 1153.3 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.3 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.3 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.3 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.2 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.2 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.2 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.2 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.2 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.1 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.1 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.1 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
#  23%|█████████▏                              | 462/2000 [00:08<00:29, 52.68it/s]
# warning: tau_max 1153.1 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.1 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.0 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.0 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.0 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.0 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.0 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1153.0 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1152.9 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1152.9 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1152.9 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1152.9 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1152.9 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1152.8 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1152.8 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1152.8 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1152.8 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1152.8 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
#  24%|█████████▌                              | 480/2000 [00:08<00:29, 52.22it/s]
# warning: tau_max 1152.8 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1152.8 exceeds cap 1000.0 (spectral gap 8.67e-03); integral will be truncated
# warning: tau_max 1152.7 exceeds cap 1000.0 (spectral gap 8.68e-03); integral will be truncated
# warning: tau_max 1152.7 exceeds cap 1000.0 (spectral gap 8.68e-03); integral will be truncated
# warning: tau_max 1152.7 exceeds cap 1000.0 (spectral gap 8.68e-03); integral will be truncated
# warning: tau_max 1152.7 exceeds cap 1000.0 (spectral gap 8.68e-03); integral will be truncated
# warning: tau_max 1152.7 exceeds cap 1000.0 (spectral gap 8.68e-03); integral will be truncated
# warning: tau_max 1152.7 exceeds cap 1000.0 (spectral gap 8.68e-03); integral will be truncated
# warning: tau_max 1152.6 exceeds cap 1000.0 (spectral gap 8.68e-03); integral will be truncated
# warning: tau_max 1152.6 exceeds cap 1000.0 (spectral gap 8.68e-03); integral will be truncated
# warning: tau_max 1152.6 exceeds cap 1000.0 (spectral gap 8.68e-03); integral will be truncated
# warning: tau_max 1152.6 exceeds cap 1000.0 (spectral gap 8.68e-03); integral will be truncated
# warning: tau_max 1152.6 exceeds cap 1000.0 (spectral gap 8.68e-03); integral will be truncated
# ...
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
#  93%|████████████████████████████████████▎  | 1859/2000 [00:41<00:03, 37.68it/s]
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
#  94%|████████████████████████████████████▍  | 1871/2000 [00:41<00:03, 37.81it/s]
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
#  94%|████████████████████████████████████▋  | 1879/2000 [00:41<00:03, 37.34it/s]
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
#  95%|████████████████████████████████████▊  | 1891/2000 [00:42<00:02, 37.19it/s]
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
#  95%|█████████████████████████████████████  | 1903/2000 [00:42<00:02, 32.87it/s]
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
#  96%|█████████████████████████████████████▎ | 1911/2000 [00:42<00:02, 34.52it/s]
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
#  96%|█████████████████████████████████████▍ | 1923/2000 [00:42<00:02, 36.11it/s]
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
#  97%|█████████████████████████████████████▋ | 1931/2000 [00:43<00:01, 36.48it/s]
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
#  97%|█████████████████████████████████████▉ | 1943/2000 [00:43<00:01, 36.71it/s]
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
#  98%|██████████████████████████████████████ | 1955/2000 [00:43<00:01, 36.49it/s]
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
#  99%|██████████████████████████████████████▍| 1971/2000 [00:44<00:00, 34.42it/s]
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
#  99%|██████████████████████████████████████▋| 1983/2000 [00:44<00:00, 35.46it/s]
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# 100%|██████████████████████████████████████▊| 1991/2000 [00:44<00:00, 35.57it/s]
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# 100%|███████████████████████████████████████| 2000/2000 [00:45<00:00, 44.32it/s]
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# warning: tau_max 1151.0 exceeds cap 1000.0 (spectral gap 8.69e-03); integral will be truncated
# B(G) at final step:
# [[ 1.92790358e-21+0.j  1.68561988e-11+0.j -1.28620437e-11+0.j
#   -3.99415509e-12+0.j]
#  [ 4.00571572e-11+0.j  1.06720193e+00+0.j -2.15437943e-01+0.j
#   -8.51763983e-01+0.j]
#  [-5.58429883e-12+0.j -1.48776765e-01+0.j  3.70878899e+00+0.j
#   -3.56001223e+00+0.j]
#  [-3.44728584e-11+0.j -9.18425161e-01+0.j -3.49335105e+00+0.j
#    4.41177621e+00+0.j]]
# False

# %%
# Steinberg curve plot
plt.plot(np.abs(affinities_c1),analytical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities_c1),numerical_areas,linewidth=1, color= 'blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 11, Figure 4D")
plt.legend()
plt.savefig("pset1_fig4d_FINAL.pdf")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
plt.savefig("pset2_4d_eigenvalues_FINAL.pdf", dpi=300)
plt.show()

# %% [markdown]
# ## Parameter set 2

# %%
labels_r = [[0.0003198327573927035, 0.008684, 0.02724], [460.7, 0.03588959409594097, 0.00104]]
labels_f = [[0.003252, 0.00104, 0.02237], [154.7, 0.0128, 0.008684]]
print(labels_f)
print(labels_r)

aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
print(aff_c1,aff_c2)

lap = lap_k4_2cycle(labels_f,labels_r)
print(lap)

# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# [[0.003252, 0.00104, 0.02237], [154.7, 0.0128, 0.008684]]
# [[0.0003198327573927035, 0.008684, 0.02724], [460.7, 0.03588959409594097, 0.00104]]
# 0.0 0.0
# [[-3.04920000e-02  3.19832757e-04  0.00000000e+00  2.23700000e-02]
#  [ 3.25200000e-03 -1.54701360e+02  4.60700000e+02  8.68400000e-03]
#  [ 0.00000000e+00  1.54700000e+02 -4.60712800e+02  3.58895941e-02]
#  [ 2.72400000e-02  1.04000000e-03  1.28000000e-02 -6.69435941e-02]]
# [-6.15409925e+02+0.j -8.11432390e-02+0.j -2.05275188e-02+0.j
#  -3.89301751e-14+0.j]

# %%
print(round_sig(0.0003198327573927035))
print(round_sig(0.03588959409594097))
# Out:
# 0.0003198
# 0.03589

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

N = 2000
affinities_c1 = np.empty(N, dtype=float)
affinities_c2 = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)
complex_steps = []

# perturb edge k21
cycle_idx = 0
edge_idx = 0
perturb_edge = labels_f[cycle_idx][edge_idx]
perturb_edge

for i in tqdm(range(0,N)):

    # make sure you perturb the correct rate in the correct data structure
    labels_f[cycle_idx][edge_idx] = perturb_edge
    
    lap = lap_k4_2cycle(labels_f, labels_r)
    
    aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
    aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
    affinities_c1[i] = aff_c1
    affinities_c2[i] = aff_c2

    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)

    order = np.lexsort((lambdas.imag, lambdas.real))
    eigvals_all_r[i, :] = lambdas.real[order]
    eigvals_all_c[i, :] = lambdas.imag[order]

    # check that the zero eigenvalue doesn't turn complex
    zero_idx = np.argmin(np.abs(lambdas))
    assert abs(lambdas.imag[zero_idx]) < 1e-12, f"zero eigenvalue went complex at step {i}"
    if np.abs(lambdas.imag).max() > 1e-9:
        complex_steps.append(i)
    
    perturb_edge *= 1.01

lambdas, w_i, z_i = spectrum_any(lap)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap))
delta_u_star = np.diag(pi)
B_final = B_matrix(lambdas, Lk_list, delta_u_star)
print("B(G) at final step:")
print(B_final)
check_symmetric(B_final, rtol=1e-05, atol=1e-08)
# Out:
# 100%|███████████████████████████████████████| 2000/2000 [00:36<00:00, 54.67it/s]
# B(G) at final step:
# [[ 7.29785842e-16+0.j -8.77813040e-09+0.j -2.94669787e-09+0.j
#    1.17248275e-08+0.j]
#  [ 6.25115538e-10+0.j  4.20309002e-01+0.j  1.40702357e-01+0.j
#   -5.61011360e-01+0.j]
#  [ 2.09297820e-10+0.j  1.40725599e-01+0.j  4.76236858e-02+0.j
#   -1.88349285e-01+0.j]
#  [-8.34414088e-10+0.j -5.61034592e-01+0.j -1.88326040e-01+0.j
#    7.49360633e-01+0.j]]
# False

# %%
# Steinberg curve plot
plt.plot(np.abs(affinities_c1),analytical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities_c1),numerical_areas,linewidth=1, color= 'blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 2, Figure 4D")
plt.legend()
plt.savefig("pset2_fig4d_FINAL.pdf")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
plt.savefig("pset2_4d_eigenvalues_FINAL.pdf", dpi=300)
plt.show()

# %% [markdown]
# ## Parameter set 3

# %%
seed = np.random.randint(0, 2**32 - 1)
print(f"seed = {2550747913}")
np.random.seed(2550747913)

labels_f, labels_r = eq_params_k4_2cycle()

print(labels_f)
print(labels_r)

aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
print(aff_c1,aff_c2)

lap = lap_k4_2cycle(labels_f,labels_r)
print(lap)

# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# seed = 2550747913
# [[0.01635, 0.006816, 1.57], [0.01181, 0.01196, 0.1465]]
# [[0.00214222209706301, 0.1465, 0.5575], [0.01815, 0.16726785621904056, 0.006816]]
# 0.0 0.0
# [[-0.57385     0.00214222  0.          1.57      ]
#  [ 0.01635    -0.02076822  0.01815     0.1465    ]
#  [ 0.          0.01181    -0.03011     0.16726786]
#  [ 0.5575      0.006816    0.01196    -1.88376786]]
# [-2.37178405e+00+0.j -9.63319113e-02+0.j -4.03801153e-02+0.j
#  -4.26031943e-17+0.j]

# %%
print(round_sig(0.00214222209706301))
print(round_sig(0.16726785621904056))
# Out:
# 0.002142
# 0.1673

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

N = 2000
affinities_c1 = np.empty(N, dtype=float)
affinities_c2 = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)
complex_steps = []

# perturb edge k21
cycle_idx = 0
edge_idx = 0
perturb_edge = labels_f[cycle_idx][edge_idx]
perturb_edge

for i in tqdm(range(0,N)):

    # make sure you perturb the correct rate in the correct data structure
    labels_f[cycle_idx][edge_idx] = perturb_edge
    
    lap = lap_k4_2cycle(labels_f, labels_r)
    
    aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
    aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
    affinities_c1[i] = aff_c1
    affinities_c2[i] = aff_c2

    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)

    order = np.lexsort((lambdas.imag, lambdas.real))
    eigvals_all_r[i, :] = lambdas.real[order]
    eigvals_all_c[i, :] = lambdas.imag[order]

    # check that the zero eigenvalue doesn't turn complex
    zero_idx = np.argmin(np.abs(lambdas))
    assert abs(lambdas.imag[zero_idx]) < 1e-12, f"zero eigenvalue went complex at step {i}"
    if np.abs(lambdas.imag).max() > 1e-9:
        complex_steps.append(i)
    
    perturb_edge *= 1.01

lambdas, w_i, z_i = spectrum_any(lap)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap))
delta_u_star = np.diag(pi)
B_final = B_matrix(lambdas, Lk_list, delta_u_star)
print("B(G) at final step:")
print(B_final)
check_symmetric(B_final, rtol=1e-05, atol=1e-08)
# Out:
# 100%|███████████████████████████████████████| 2000/2000 [00:35<00:00, 56.27it/s]
# B(G) at final step:
# [[ 1.63502036e-16+0.j -1.85738076e-09+0.j  1.35150229e-09+0.j
#    5.05878311e-10+0.j]
#  [ 8.55011064e-09+0.j  5.03190599e+00+0.j -5.05265644e+00+0.j
#    2.07504420e-02+0.j]
#  [-8.52414945e-09+0.j -5.01662720e+00+0.j  5.03964068e+00+0.j
#   -2.30134736e-02+0.j]
#  [-2.59613544e-11+0.j -1.52787889e-02+0.j  1.30157578e-02+0.j
#    2.26303109e-03+0.j]]
# False

# %%
# Steinberg curve plot
plt.plot(np.abs(affinities_c1),analytical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities_c1),numerical_areas,linewidth=1, color= 'blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 3, Figure 4D")
plt.legend()
plt.savefig("pset3_fig4d_FINAL.pdf")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
plt.savefig("pset3_4d_eigenvalues_FINAL.pdf", dpi=300)
plt.show()

# %% [markdown]
# # Parameter sweeps

# %%
import json
hits = []
for _ in range(200):
    seed = np.random.randint(0, 2**32 - 1)
    np.random.seed(seed)
    lf, lr = eq_params_k4_2cycle()
    flat = lf[0] + lf[1] + lr[0] + lr[1]
    ratio = max(flat) / min(flat)
    if ratio > 1e8:
        continue
    lap = lap_k4_2cycle(lf, lr)
    if steinberg_analytical_area(signal, lap) > 1e-6:
        continue
    hits.append((seed, ratio))

with open("candidate_seeds_k4prime.log", "a") as fh:
    for s, r in hits:
        fh.write(json.dumps({"seed": s, "ratio": r}) + "\n")
print(f"{len(hits)} well-conditioned candidates logged")
# Out:
# 135 well-conditioned candidates logged

# %%
for s, r in hits:
    print(f"seed {s}   spread ratio {r:.1e}")
# Out:
# seed 424765185   spread ratio 8.1e+03
# seed 2682807654   spread ratio 1.2e+05
# seed 3995015656   spread ratio 1.5e+04
# seed 2538217648   spread ratio 5.1e+03
# seed 2766600765   spread ratio 2.4e+05
# seed 2410126343   spread ratio 6.6e+05
# seed 2941560579   spread ratio 1.8e+04
# seed 3543165634   spread ratio 3.7e+05
# seed 3537159740   spread ratio 1.6e+05
# seed 1584732493   spread ratio 7.8e+03
# seed 317166652   spread ratio 3.4e+05
# seed 2591495996   spread ratio 5.1e+04
# seed 2663138956   spread ratio 2.6e+06
# seed 3903643449   spread ratio 1.7e+05
# seed 1907055555   spread ratio 4.9e+04
# seed 1002788843   spread ratio 1.6e+03
# seed 3620399884   spread ratio 7.0e+04
# seed 1535060969   spread ratio 5.1e+04
# seed 3049328013   spread ratio 3.6e+04
# seed 1044263482   spread ratio 1.1e+03
# seed 3034200876   spread ratio 9.9e+03
# seed 2433516132   spread ratio 2.1e+06
# seed 3424977317   spread ratio 1.9e+05
# seed 3532379721   spread ratio 1.6e+05
# seed 3657879619   spread ratio 4.7e+04
# seed 1630428214   spread ratio 4.5e+06
# seed 3957537113   spread ratio 2.2e+05
# seed 3621164766   spread ratio 1.3e+07
# seed 3674879485   spread ratio 5.2e+06
# seed 2552511541   spread ratio 7.6e+06
# seed 4158467726   spread ratio 6.5e+06
# seed 1022884283   spread ratio 1.0e+08
# seed 272257357   spread ratio 6.4e+06
# seed 3156212953   spread ratio 1.5e+06
# seed 3086788609   spread ratio 7.1e+06
# seed 4121183267   spread ratio 1.6e+07
# seed 2402765262   spread ratio 9.9e+03
# seed 3875021228   spread ratio 8.0e+06
# seed 2343084260   spread ratio 1.0e+03
# seed 674411026   spread ratio 1.1e+04
# seed 1628437710   spread ratio 4.4e+05
# seed 311550282   spread ratio 1.5e+04
# seed 2746690385   spread ratio 4.6e+04
# seed 2030493964   spread ratio 2.3e+06
# seed 1159083388   spread ratio 9.6e+04
# seed 3850591929   spread ratio 1.5e+05
# seed 2391525150   spread ratio 9.2e+04
# seed 3083619461   spread ratio 9.2e+07
# seed 702733392   spread ratio 8.4e+05
# seed 3079947601   spread ratio 1.6e+05
# seed 3233114154   spread ratio 1.5e+06
# seed 935443693   spread ratio 2.1e+04
# seed 1798921127   spread ratio 1.5e+07
# seed 754984440   spread ratio 2.7e+05
# seed 2902526954   spread ratio 5.9e+04
# seed 894427168   spread ratio 5.6e+04
# seed 185840071   spread ratio 7.6e+04
# seed 3790616308   spread ratio 1.1e+07
# seed 2958538510   spread ratio 7.2e+07
# seed 4171736543   spread ratio 3.7e+05
# seed 1954712827   spread ratio 1.6e+06
# seed 187957529   spread ratio 1.9e+03
# seed 1322471182   spread ratio 7.5e+06
# seed 1270103512   spread ratio 1.8e+05
# seed 3194239476   spread ratio 1.9e+05
# seed 3390884048   spread ratio 4.5e+05
# seed 103131033   spread ratio 2.8e+04
# seed 3234030994   spread ratio 2.1e+07
# seed 4082269419   spread ratio 1.4e+03
# seed 2705850871   spread ratio 2.8e+07
# seed 2692176086   spread ratio 3.5e+04
# seed 3432510825   spread ratio 5.4e+06
# seed 3855129129   spread ratio 1.5e+03
# seed 1429833068   spread ratio 8.8e+04
# seed 1610640159   spread ratio 4.1e+07
# seed 3756831602   spread ratio 5.1e+06
# seed 601008671   spread ratio 4.2e+05
# seed 2736621235   spread ratio 3.1e+04
# seed 3163843117   spread ratio 6.4e+05
# seed 3709183279   spread ratio 2.9e+07
# seed 3377358337   spread ratio 4.0e+06
# seed 3537430728   spread ratio 2.9e+04
# seed 1019756560   spread ratio 5.8e+07
# seed 3955440024   spread ratio 2.4e+03
# seed 2118029057   spread ratio 3.3e+05
# seed 600430783   spread ratio 2.6e+04
# seed 2574214886   spread ratio 1.1e+04
# seed 2150232245   spread ratio 9.4e+04
# seed 899214399   spread ratio 4.2e+06
# seed 1711303649   spread ratio 3.7e+05
# seed 175540332   spread ratio 1.2e+04
# seed 2597876832   spread ratio 4.0e+06
# seed 2096659210   spread ratio 3.3e+05
# seed 4291181635   spread ratio 2.6e+07
# seed 982653532   spread ratio 9.3e+05
# seed 709284106   spread ratio 1.6e+07
# seed 2620454156   spread ratio 1.1e+06
# seed 1415909513   spread ratio 2.6e+04
# seed 2337513506   spread ratio 3.2e+04
# seed 3506824432   spread ratio 4.7e+05
# seed 159418135   spread ratio 3.2e+06
# seed 1337466168   spread ratio 2.5e+05
# seed 3455702799   spread ratio 2.8e+04
# seed 800037803   spread ratio 6.1e+05
# seed 2475600118   spread ratio 3.5e+05
# seed 1115631533   spread ratio 1.3e+06
# seed 291963998   spread ratio 7.4e+07
# seed 2687013679   spread ratio 2.6e+07
# seed 3648467607   spread ratio 2.8e+06
# seed 3989498410   spread ratio 9.0e+06
# seed 1607967   spread ratio 2.9e+05
# seed 2928896624   spread ratio 6.0e+04
# seed 3387965843   spread ratio 6.9e+06
# seed 2253953602   spread ratio 2.7e+03
# seed 1963882196   spread ratio 1.1e+04
# seed 1394101579   spread ratio 2.6e+07
# seed 1694543309   spread ratio 2.1e+07
# seed 1161255704   spread ratio 3.3e+04
# seed 467596763   spread ratio 4.7e+05
# seed 1360113410   spread ratio 6.7e+04
# seed 2162198865   spread ratio 5.2e+03
# seed 1220627215   spread ratio 7.2e+07
# seed 3843047038   spread ratio 4.0e+05
# seed 4041150859   spread ratio 6.3e+07
# seed 342712541   spread ratio 1.2e+06
# seed 2947311463   spread ratio 3.0e+04
# seed 854820466   spread ratio 3.1e+05
# seed 1888874970   spread ratio 5.0e+04
# seed 3863078997   spread ratio 6.7e+04
# seed 4055783995   spread ratio 7.8e+06
# seed 2121047976   spread ratio 5.9e+04
# seed 2138278331   spread ratio 2.0e+07
# seed 2108396754   spread ratio 5.7e+07
# seed 346799560   spread ratio 2.9e+04
# seed 864206828   spread ratio 4.4e+04

# %%
def curve_summary(seed, N=500):
    np.random.seed(seed)
    lf, lr = eq_params_k4_2cycle()
    base = lf[0][0]                      # k21
    areas, affs = [], []
    for i in range(N):
        lf[0][0] = base * 1.01**i
        lap = lap_k4_2cycle(lf, lr)
        areas.append(steinberg_analytical_area(signal, lap))
        affs.append(np.abs(np.log(np.prod(lf[0]) / np.prod(lr[0]))))
    areas, affs = np.array(areas), np.array(affs)
    return areas.max(), affs[areas.argmax()], areas[-1]

for s, r in hits:
    peak, at, end = curve_summary(s)
    print(f"seed {s}  peak {peak:.4g} at aff {at:.2f}  ends {end:.4g}  "
          f"drop {peak/max(end,1e-30):.1e}")
# Out:
# seed 424765185  peak 0.604 at aff 3.11  ends 0.2769  drop 2.2e+00
# seed 2682807654  peak 6.044 at aff 1.22  ends 0.3993  drop 1.5e+01
# seed 3995015656  peak 7.76 at aff 1.64  ends 0.8698  drop 8.9e+00
# seed 2538217648  peak 42.79 at aff 3.07  ends 20.36  drop 2.1e+00
# seed 2766600765  peak 0.4895 at aff 0.95  ends 0.02201  drop 2.2e+01
# seed 2410126343  peak 2.906e-05 at aff 4.97  ends 2.906e-05  drop 1.0e+00
# seed 2941560579  peak 477.7 at aff 3.33  ends 257.7  drop 1.9e+00
# seed 3543165634  peak 0.01541 at aff 2.53  ends 0.01195  drop 1.3e+00
# seed 3537159740  peak 0.02821 at aff 1.56  ends 0.004382  drop 6.4e+00
# seed 1584732493  peak 14.81 at aff 2.82  ends 5.308  drop 2.8e+00
# seed 317166652  peak 0.0005704 at aff 1.03  ends 0.0002366  drop 2.4e+00
# seed 2591495996  peak 0.0004852 at aff 3.15  ends 0.0002373  drop 2.0e+00
# seed 2663138956  peak 0.01332 at aff 1.14  ends 0.0007746  drop 1.7e+01
# seed 3903643449  peak 0.001603 at aff 0.90  ends 6.353e-05  drop 2.5e+01
# seed 1907055555  peak 1.581e-05 at aff 1.02  ends 1.102e-05  drop 1.4e+00
# seed 1002788843  peak 0.2489 at aff 1.57  ends 0.02619  drop 9.5e+00
# seed 3620399884  peak 0.036 at aff 1.28  ends 0.0145  drop 2.5e+00
# seed 1535060969  peak 4.032e-06 at aff 0.72  ends 1.704e-07  drop 2.4e+01
# seed 3049328013  peak 3.721e-06 at aff 0.70  ends 1.352e-07  drop 2.8e+01
# seed 1044263482  peak 0.4553 at aff 0.87  ends 0.07725  drop 5.9e+00
# seed 3034200876  peak 1.625e-06 at aff 0.74  ends 5.362e-08  drop 3.0e+01
# seed 2433516132  peak 1.18 at aff 3.20  ends 0.5757  drop 2.1e+00
# seed 3424977317  peak 8.894e-05 at aff 2.83  ends 4.376e-05  drop 2.0e+00
# seed 3532379721  peak 1.094e-05 at aff 0.70  ends 3.763e-07  drop 2.9e+01
# seed 3657879619  peak 5.501e-05 at aff 0.86  ends 2.56e-05  drop 2.1e+00
# seed 1630428214  peak 0.4331 at aff 0.89  ends 0.01691  drop 2.6e+01
# seed 3957537113  peak 1.101 at aff 0.81  ends 0.03862  drop 2.8e+01
# seed 3621164766  peak 1.602e-05 at aff 4.97  ends 1.602e-05  drop 1.0e+00
# seed 3674879485  peak 2.196e-06 at aff 4.97  ends 2.196e-06  drop 1.0e+00
# seed 2552511541  peak 1.396e-08 at aff 4.97  ends 1.396e-08  drop 1.0e+00
# seed 4158467726  peak 0.02197 at aff 0.79  ends 0.0007303  drop 3.0e+01
# seed 1022884283  peak 6.867e-05 at aff 2.93  ends 2.904e-05  drop 2.4e+00
# seed 272257357  peak 1.07 at aff 3.82  ends 0.7878  drop 1.4e+00
# seed 3156212953  peak 0.03861 at aff 4.97  ends 0.03861  drop 1.0e+00
# seed 3086788609  peak 0.001319 at aff 4.97  ends 0.001319  drop 1.0e+00
# seed 4121183267  peak 0.005498 at aff 2.61  ends 0.001655  drop 3.3e+00
# seed 2402765262  peak 0.02083 at aff 3.54  ends 0.01299  drop 1.6e+00
# seed 3875021228  peak 0.001359 at aff 3.04  ends 0.0005863  drop 2.3e+00
# seed 2343084260  peak 2.218 at aff 1.61  ends 0.7298  drop 3.0e+00
# seed 674411026  peak 0.02015 at aff 4.97  ends 0.02015  drop 1.0e+00
# seed 1628437710  peak 0.01132 at aff 2.10  ends 0.002448  drop 4.6e+00
# seed 311550282  peak 0.7268 at aff 4.97  ends 0.7268  drop 1.0e+00
# seed 2746690385  peak 1.23 at aff 3.81  ends 0.9497  drop 1.3e+00
# seed 2030493964  peak 0.002165 at aff 4.97  ends 0.002165  drop 1.0e+00
# seed 1159083388  peak 0.1103 at aff 1.01  ends 0.005447  drop 2.0e+01
# seed 3850591929  peak 0.1157 at aff 4.97  ends 0.1157  drop 1.0e+00
# seed 2391525150  peak 0.001355 at aff 4.97  ends 0.001355  drop 1.0e+00
# seed 3083619461  peak 5.253e-05 at aff 4.15  ends 4.463e-05  drop 1.2e+00
# seed 702733392  peak 0.005314 at aff 4.93  ends 0.005312  drop 1.0e+00
# seed 3079947601  peak 0.0005938 at aff 4.97  ends 0.0005938  drop 1.0e+00
# seed 3233114154  peak 8.621e-06 at aff 4.97  ends 8.621e-06  drop 1.0e+00
# seed 935443693  peak 0.04193 at aff 2.42  ends 0.01044  drop 4.0e+00
# seed 1798921127  peak 0.002108 at aff 0.94  ends 9.536e-05  drop 2.2e+01
# seed 754984440  peak 0.005276 at aff 4.97  ends 0.005276  drop 1.0e+00
# seed 2902526954  peak 0.1422 at aff 0.80  ends 0.03556  drop 4.0e+00
# seed 894427168  peak 0.5797 at aff 4.97  ends 0.5797  drop 1.0e+00
# seed 185840071  peak 0.01007 at aff 1.06  ends 0.0005202  drop 1.9e+01
# seed 3790616308  peak 2.681e-07 at aff 4.97  ends 2.681e-07  drop 1.0e+00
# seed 2958538510  peak 2.961e-08 at aff 1.48  ends 4.879e-09  drop 6.1e+00
# seed 4171736543  peak 0.0004036 at aff 0.73  ends 1.202e-05  drop 3.4e+01
# seed 1954712827  peak 0.3061 at aff 0.96  ends 0.04051  drop 7.6e+00
# seed 187957529  peak 0.2834 at aff 0.82  ends 0.01035  drop 2.7e+01
# seed 1322471182  peak 38.93 at aff 4.97  ends 38.93  drop 1.0e+00
# seed 1270103512  peak 0.004381 at aff 0.92  ends 0.0001801  drop 2.4e+01
# seed 3194239476  peak 0.002837 at aff 4.97  ends 0.002837  drop 1.0e+00
# seed 3390884048  peak 0.02639 at aff 2.01  ends 0.004366  drop 6.0e+00
# seed 103131033  peak 0.2776 at aff 1.15  ends 0.01657  drop 1.7e+01
# seed 3234030994  peak 0.00744 at aff 0.88  ends 0.0002885  drop 2.6e+01
# seed 4082269419  peak 0.006247 at aff 0.90  ends 0.0003242  drop 1.9e+01
# seed 2705850871  peak 0.01322 at aff 4.97  ends 0.01322  drop 1.0e+00
# seed 2692176086  peak 1.553e-06 at aff 1.19  ends 2.78e-07  drop 5.6e+00
# seed 3432510825  peak 2.859e-08 at aff 4.97  ends 2.859e-08  drop 1.0e+00
# seed 3855129129  peak 27.58 at aff 2.87  ends 10.36  drop 2.7e+00
# seed 1429833068  peak 0.1331 at aff 4.97  ends 0.1331  drop 1.0e+00
# seed 1610640159  peak 5.763e-08 at aff 4.97  ends 5.763e-08  drop 1.0e+00
# seed 3756831602  peak 0.5649 at aff 1.25  ends 0.05116  drop 1.1e+01
# seed 601008671  peak 0.353 at aff 3.19  ends 0.1711  drop 2.1e+00
# seed 2736621235  peak 0.003562 at aff 0.82  ends 0.0001243  drop 2.9e+01
# seed 3163843117  peak 1.147e-06 at aff 0.83  ends 4.408e-07  drop 2.6e+00
# seed 3709183279  peak 0.08158 at aff 1.92  ends 0.01236  drop 6.6e+00
# seed 3377358337  peak 0.03997 at aff 2.89  ends 0.0152  drop 2.6e+00
# seed 3537430728  peak 0.2831 at aff 1.75  ends 0.03786  drop 7.5e+00
# seed 1019756560  peak 1.633e-07 at aff 0.75  ends 5.572e-09  drop 2.9e+01
# seed 3955440024  peak 0.06395 at aff 1.01  ends 0.003327  drop 1.9e+01
# seed 2118029057  peak 3.965e-06 at aff 4.97  ends 3.965e-06  drop 1.0e+00
# seed 600430783  peak 0.01239 at aff 0.91  ends 0.00604  drop 2.1e+00
# seed 2574214886  peak 0.01473 at aff 0.92  ends 0.00061  drop 2.4e+01
# seed 2150232245  peak 0.0172 at aff 1.86  ends 0.002707  drop 6.4e+00
# seed 899214399  peak 0.1148 at aff 2.42  ends 0.02898  drop 4.0e+00
# seed 1711303649  peak 3.177e-06 at aff 4.97  ends 3.177e-06  drop 1.0e+00
# seed 175540332  peak 0.127 at aff 2.99  ends 0.0527  drop 2.4e+00
# seed 2597876832  peak 0.01089 at aff 1.20  ends 0.0006923  drop 1.6e+01
# seed 2096659210  peak 2.025e-05 at aff 0.89  ends 1.041e-06  drop 1.9e+01
# seed 4291181635  peak 0.1335 at aff 4.97  ends 0.1335  drop 1.0e+00
# seed 982653532  peak 0.0001526 at aff 2.40  ends 6.335e-05  drop 2.4e+00
# seed 709284106  peak 1.512e-07 at aff 0.70  ends 5.52e-09  drop 2.7e+01
# seed 2620454156  peak 1.86e-06 at aff 2.78  ends 1.13e-06  drop 1.6e+00
# seed 1415909513  peak 0.0001229 at aff 0.72  ends 3.581e-06  drop 3.4e+01
# seed 2337513506  peak 0.1419 at aff 4.97  ends 0.1419  drop 1.0e+00
# seed 3506824432  peak 0.01105 at aff 3.05  ends 0.005055  drop 2.2e+00
# seed 159418135  peak 0.0007929 at aff 4.97  ends 0.0007929  drop 1.0e+00
# seed 1337466168  peak 0.003458 at aff 4.97  ends 0.003458  drop 1.0e+00
# seed 3455702799  peak 0.758 at aff 1.39  ends 0.06517  drop 1.2e+01
# seed 800037803  peak 0.003198 at aff 1.60  ends 0.002045  drop 1.6e+00
# seed 2475600118  peak 0.006445 at aff 3.47  ends 0.003843  drop 1.7e+00
# seed 1115631533  peak 0.000438 at aff 1.79  ends 8.791e-05  drop 5.0e+00
# seed 291963998  peak 1.154e-05 at aff 3.75  ends 8.359e-06  drop 1.4e+00
# seed 2687013679  peak 0.0003311 at aff 4.97  ends 0.0003311  drop 1.0e+00
# seed 3648467607  peak 4.798e-05 at aff 4.97  ends 4.798e-05  drop 1.0e+00
# seed 3989498410  peak 0.001865 at aff 1.10  ends 0.0001025  drop 1.8e+01
# seed 1607967  peak 0.002034 at aff 1.47  ends 0.000249  drop 8.2e+00
# seed 2928896624  peak 0.006176 at aff 0.72  ends 0.0002873  drop 2.1e+01
# seed 3387965843  peak 0.1642 at aff 1.51  ends 0.02476  drop 6.6e+00
# seed 2253953602  peak 5.472e-06 at aff 0.92  ends 2.933e-06  drop 1.9e+00
# seed 1963882196  peak 0.07648 at aff 1.47  ends 0.007022  drop 1.1e+01
# seed 1394101579  peak 0.002378 at aff 2.21  ends 0.0004859  drop 4.9e+00
# seed 1694543309  peak 0.0002879 at aff 0.80  ends 9.739e-06  drop 3.0e+01
# seed 1161255704  peak 0.04342 at aff 4.97  ends 0.04342  drop 1.0e+00
# seed 467596763  peak 0.9073 at aff 4.97  ends 0.9073  drop 1.0e+00
# seed 1360113410  peak 0.00228 at aff 4.97  ends 0.00228  drop 1.0e+00
# seed 2162198865  peak 4.962 at aff 4.97  ends 4.962  drop 1.0e+00
# seed 1220627215  peak 1.345e-07 at aff 1.83  ends 1.855e-08  drop 7.3e+00
# seed 3843047038  peak 0.004293 at aff 1.40  ends 0.002237  drop 1.9e+00
# seed 4041150859  peak 4.811e-08 at aff 1.20  ends 4.275e-09  drop 1.1e+01
# seed 342712541  peak 0.01329 at aff 3.01  ends 0.006147  drop 2.2e+00
# seed 2947311463  peak 0.1152 at aff 1.00  ends 0.005453  drop 2.1e+01
# seed 854820466  peak 0.07832 at aff 4.82  ends 0.07794  drop 1.0e+00
# seed 1888874970  peak 0.0009053 at aff 4.97  ends 0.0009053  drop 1.0e+00
# seed 3863078997  peak 0.06707 at aff 4.97  ends 0.06707  drop 1.0e+00
# seed 4055783995  peak 0.4194 at aff 0.85  ends 0.01531  drop 2.7e+01
# seed 2121047976  peak 0.008162 at aff 0.86  ends 0.0007109  drop 1.1e+01
# seed 2138278331  peak 0.00508 at aff 1.94  ends 0.0007882  drop 6.4e+00
# seed 2108396754  peak 3.686e-05 at aff 0.82  ends 1.568e-06  drop 2.4e+01
# seed 346799560  peak 0.7662 at aff 4.97  ends 0.7662  drop 1.0e+00
# seed 864206828  peak 0.0002093 at aff 0.88  ends 0.0001049  drop 2.0e+00

# %%
import json

def curve_peak(seed, N=500):
    np.random.seed(seed)
    lf, lr = eq_params_k4_2cycle()
    flat = lf[0] + lf[1] + lr[0] + lr[1]
    ratio = max(flat) / min(flat)
    lap = lap_k4_2cycle(lf, lr)
    if ratio > 1e8 or steinberg_analytical_area(signal, lap) > 1e-6:
        return None
    base = lr[0][0]                      # k12
    areas, affs = [], []
    for i in range(N):
        lr[0][0] = base * 1.01**i
        lap = lap_k4_2cycle(lf, lr)
        areas.append(steinberg_analytical_area(signal, lap))
        affs.append(np.abs(np.log(np.prod(lf[0]) / np.prod(lr[0]))))
    areas, affs = np.array(areas), np.array(affs)
    return areas.max(), affs[areas.argmax()], areas[-1], ratio

PEAK_MIN = 10.0
for _ in range(300):
    seed = np.random.randint(0, 2**32 - 1)
    res = curve_peak(seed)
    if res is None:
        continue
    peak, at, end, ratio = res
    if peak < PEAK_MIN:
        continue
    print(f"seed {seed}  peak {peak:.4g} at aff {at:.2f}  ends {end:.4g}  "
          f"drop {peak/max(end,1e-30):.1e}  ratio {ratio:.1e}")
    with open("candidate_seeds_k4prime.log", "a") as fh:
        fh.write(json.dumps({"seed": int(seed), "peak": peak, "aff_at_peak": at,
                             "end": end, "ratio": ratio}) + "\n")
# Out:
# seed 1044263482  peak 95.77 at aff 4.97  ends 95.77  drop 1.0e+00  ratio 1.1e+03
# seed 3537430728  peak 21.65 at aff 4.97  ends 21.65  drop 1.0e+00  ratio 2.9e+04
# seed 3827489457  peak 79.08 at aff 2.62  ends 26.59  drop 3.0e+00  ratio 2.0e+03
# seed 2550747913  peak 225.9 at aff 3.44  ends 151  drop 1.5e+00  ratio 7.3e+02
# seed 520888101  peak 123.2 at aff 1.90  ends 18.23  drop 6.8e+00  ratio 3.1e+04
# seed 1651563432  peak 32.83 at aff 4.97  ends 32.83  drop 1.0e+00  ratio 8.5e+07

# %%
def classify(seed, which, cyc, edge, N=2000):
    np.random.seed(seed)
    lf, lr = eq_params_k4_2cycle()
    tgt = lf if which == 'f' else lr
    base = tgt[cyc][edge]
    areas, affs = [], []
    for i in range(N):
        tgt[cyc][edge] = base * 1.01**i
        lr[1][2] = lf[0][1]        # keep k42 copies in sync
        lr[0][1] = lf[1][2]        # keep k24 copies in sync
        lap = lap_k4_2cycle(lf, lr)
        areas.append(steinberg_analytical_area(signal, lap))
        affs.append(np.abs(np.log(np.prod(lf[0]) / np.prod(lr[0]))))
    areas, affs = np.array(areas), np.array(affs)
    k = areas.argmax()
    kind = 'monotone' if k >= N - 5 else 'peaked'
    return kind, areas.max(), affs[k], areas[-1], areas, affs

# %% [markdown]
# ## Other candidates for curve 1

# %%
seed = np.random.randint(0, 2**32 - 1)
print(f"seed = {1427402468}")
np.random.seed(1427402468)

labels_f, labels_r = eq_params_k4_2cycle()

print(labels_f)
print(labels_r)

aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
print(aff_c1,aff_c2)

lap = lap_k4_2cycle(labels_f,labels_r)
print(lap)

# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# seed = 1427402468
# [[0.05302, 222.5, 3.983], [28.43, 0.06275, 0.08065]]
# [[34130.460839016334, 0.08065, 0.01707], [0.7312, 0.0008843593331263986, 222.5]]
# 1.1102230246251565e-16 0.0
# [[-7.00900000e-02  3.41304608e+04  0.00000000e+00  3.98300000e+00]
#  [ 5.30200000e-02 -3.43813908e+04  7.31200000e-01  8.06500000e-02]
#  [ 0.00000000e+00  2.84300000e+01 -7.93950000e-01  8.84359333e-04]
#  [ 1.70700000e-02  2.22500000e+02  6.27500000e-02 -4.06453436e+00]]
# [-3.43814446e+04+0.j -4.08143936e+00+0.j -7.93375386e-01+0.j
#  -1.29945116e-14+0.j]

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

N = 2000
affinities_c1 = np.empty(N, dtype=float)
affinities_c2 = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)
complex_steps = []

# perturb edge k32
cycle_idx = 1
edge_idx = 0
perturb_edge = labels_f[cycle_idx][edge_idx]
perturb_edge

for i in tqdm(range(0,N)):

    # make sure you perturb the correct rate in the correct data structure
    labels_f[cycle_idx][edge_idx] = perturb_edge
    
    lap = lap_k4_2cycle(labels_f, labels_r)
    
    aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
    aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
    affinities_c1[i] = aff_c1
    affinities_c2[i] = aff_c2

    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)

    order = np.lexsort((lambdas.imag, lambdas.real))
    eigvals_all_r[i, :] = lambdas.real[order]
    eigvals_all_c[i, :] = lambdas.imag[order]

    # check that the zero eigenvalue doesn't turn complex
    zero_idx = np.argmin(np.abs(lambdas))
    assert abs(lambdas.imag[zero_idx]) < 1e-12, f"zero eigenvalue went complex at step {i}"
    if np.abs(lambdas.imag).max() > 1e-9:
        complex_steps.append(i)
    
    perturb_edge *= 1.01

lambdas, w_i, z_i = spectrum_any(lap)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap))
delta_u_star = np.diag(pi)
B_final = B_matrix(lambdas, Lk_list, delta_u_star)
print("B(G) at final step:")
print(B_final)
check_symmetric(B_final, rtol=1e-05, atol=1e-08)
# Out:
# 100%|███████████████████████████████████████| 2000/2000 [00:46<00:00, 43.02it/s]
# B(G) at final step:
# [[ 2.13968583e+00+0.j -1.39615430e-10+0.j -2.17447971e+00+0.j
#    3.47938816e-02+0.j]
#  [-1.16043045e-10+0.j  9.96942673e-21+0.j  1.18048935e-10+0.j
#   -2.00588931e-12+0.j]
#  [-2.11480475e+00+0.j  1.38137021e-10+0.j  2.15145381e+00+0.j
#   -3.66490591e-02+0.j]
#  [-2.48810758e-02+0.j  1.47840892e-12+0.j  2.30258983e-02+0.j
#    1.85517750e-03+0.j]]
# False

# %%
# Steinberg curve plot
plt.plot(np.abs(affinities_c2),analytical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities_c2),numerical_areas,linewidth=1, color= 'blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 11, Figure 4D")
plt.legend()
plt.savefig("pset11_fig4d_260809.pdf")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
#plt.savefig("pset6_eigenvalues_260809.pdf", dpi=300)
plt.show()

# %%
labels_f = [[0.2078, 0.01814, 0.009067], [0.1904, 0.03504, 0.01012]]
labels_r = [[1.4184255114186253e-05, 0.01012, 238.1], [0.8715, 0.004270776849404232, 0.01814]]
print(labels_f)
print(labels_r)

aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
print(aff_c1,aff_c2)

lap = lap_k4_2cycle(labels_f,labels_r)
print(lap)

# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# [[0.2078, 0.01814, 0.009067], [0.1904, 0.03504, 0.01012]]
# [[1.4184255114186253e-05, 0.01012, 238.1], [0.8715, 0.004270776849404232, 0.01814]]
# 0.0 0.0
# [[-2.38307800e+02  1.41842551e-05  0.00000000e+00  9.06700000e-03]
#  [ 2.07800000e-01 -2.08554184e-01  8.71500000e-01  1.01200000e-02]
#  [ 0.00000000e+00  1.90400000e-01 -9.06540000e-01  4.27077685e-03]
#  [ 2.38100000e+02  1.81400000e-02  3.50400000e-02 -2.34577768e-02]]
# [-2.38316860e+02+0.j -1.09397894e+00+0.j -3.55133698e-02+0.j
#   1.66903793e-15+0.j]

# %%
print(round_sig(1.4184255114186253e-05))
print(round_sig(0.004270776849404232))
# Out:
# 1.418e-05
# 0.004271

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

N = 2000
affinities_c1 = np.empty(N, dtype=float)
affinities_c2 = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)
complex_steps = []

# perturb edge k21
cycle_idx = 0
edge_idx = 0
perturb_edge = labels_f[cycle_idx][edge_idx]
perturb_edge

for i in tqdm(range(0,N)):

    # make sure you perturb the correct rate in the correct data structure
    labels_f[cycle_idx][edge_idx] = perturb_edge
    
    lap = lap_k4_2cycle(labels_f, labels_r)
    
    aff_c1 = np.abs(np.log(np.prod(labels_f[0])/np.prod(labels_r[0])))
    aff_c2 = np.abs(np.log(np.prod(labels_f[1])/np.prod(labels_r[1])))
    affinities_c1[i] = aff_c1
    affinities_c2[i] = aff_c2

    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)

    order = np.lexsort((lambdas.imag, lambdas.real))
    eigvals_all_r[i, :] = lambdas.real[order]
    eigvals_all_c[i, :] = lambdas.imag[order]

    # check that the zero eigenvalue doesn't turn complex
    zero_idx = np.argmin(np.abs(lambdas))
    assert abs(lambdas.imag[zero_idx]) < 1e-12, f"zero eigenvalue went complex at step {i}"
    if np.abs(lambdas.imag).max() > 1e-9:
        complex_steps.append(i)
    
    perturb_edge *= 1.01

lambdas, w_i, z_i = spectrum_any(lap)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap))
delta_u_star = np.diag(pi)
B_final = B_matrix(lambdas, Lk_list, delta_u_star)
print("B(G) at final step:")
print(B_final)
check_symmetric(B_final, rtol=1e-05, atol=1e-08)
# Out:
# 100%|███████████████████████████████████████| 2000/2000 [00:39<00:00, 51.03it/s]
# B(G) at final step:
# [[ 4.75808928e-19+0.j -4.63689116e-10+0.j -9.65591863e-11+0.j
#    5.60248302e-10+0.j]
#  [ 4.26683777e-10+0.j  3.87959666e+00+0.j  7.23112388e-01+0.j
#   -4.60270905e+00+0.j]
#  [ 8.23253723e-11+0.j  7.48538754e-01+0.j  2.40523540e-01+0.j
#   -9.89062294e-01+0.j]
#  [-5.09009150e-10+0.j -4.62813541e+00+0.j -9.63635928e-01+0.j
#    5.59177134e+00+0.j]]
# False

# %%
# Steinberg curve plot
plt.plot(np.abs(affinities_c1),analytical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities_c1),numerical_areas,linewidth=1, color= 'blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 1, Figure 4D")
plt.legend()
plt.savefig("pset111_fig4d_260819.pdf")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities_c1, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
plt.savefig("pset111_4d_eigenvalues.pdf", dpi=300)
plt.show()
