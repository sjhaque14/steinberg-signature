# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import networkx as nx
import scipy.linalg

from steinberg import *

plt.rc("text", usetex=False)
plt.rc("font", family = "serif",size=14)
plt.rc("figure",figsize=(10,8))
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# Here, we define specific parameter sampling and Laplacian computing functions for the graph $K_4$. $K_4$ is the 4-cycle graph.

# %%
def eq_params_k4():
    """
    Samples equilibrium parameter sets for a 4-state single-cycle graph
    (k12, k23, k34, k41) and (k21, k32, k43, k14), ensuring zero cycle affinity.

    Returns
    -------
    labels_f : list of 4 floats
        Forward rates: [k21, k32, k43, k14]
    labels_r : list of 4 floats
        Reverse rates: [k12, k23, k34, k41]
    """

    # Sample 7 of the 8 parameters freely
    k12 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k23 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k34 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k41 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)

    k21 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k32 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k43 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)

    # Solve for k14 to make the cycle affinity zero
    # A(C) = log[(k12 k23 k34 k41)/(k21 k32 k43 k14)] = 0 → solve for k14
    k14 = (k12 * k23 * k34 * k41) / (k21 * k32 * k43)

    labels_f = [k21, k32, k43, k14]   # forward cycle 1->2->3->4->1
    labels_r = [k12, k23, k34, k41]   # reverse cycle 1->4->3->2->1

    return labels_f, labels_r

def params_shuffle_k4(params):
    """
    Takes randomly sampled parameters from random_parameters(num_params) and converts to labels_f and labels_r strcuture

    Returns
    -------
    labels_f : list of 4 floats
        Forward rates: [k21, k32, k43, k14]
    labels_r : list of 4 floats
        Reverse rates: [k12, k23, k34, k41]
    """
    k12 = params[0]
    k23 = params[1]
    k34 = params[2]
    k41 = params[3]

    k21 = params[4]
    k32 = params[5]
    k43 = params[6]
    k14 = params[7]

    labels_f = [k21, k32, k43, k14]   # forward cycle 1->2->3->4->1
    labels_r = [k12, k23, k34, k41]   # reverse cycle 1->4->3->2->1

    return labels_f, labels_r
    
def lap_k4(labels_f, labels_r):
    """
    Column-based Laplacian for the 4-vertex single-cycle graph K_4.

    Convention (Fig. 1C): k_ij = l(j -> i), so L[i,j] = k_ij for i != j
    and L[i,i] = -sum_k l(i -> k).

    labels_f : [k21, k32, k43, k14]   forward cycle 1->2->3->4->1
    labels_r : [k12, k23, k34, k41]   reverse cycle 1->4->3->2->1
    """
    k21, k32, k43, k14 = labels_f
    k12, k23, k34, k41 = labels_r

    return np.array([
        [-(k21 + k41),  k12,           0,            k14         ],
        [  k21,        -(k12 + k32),   k23,          0           ],
        [  0,           k32,          -(k23 + k43),  k34         ],
        [  k41,         0,             k43,         -(k14 + k34) ]], dtype=float)

# %% [markdown]
# Next, we perform a few sanity checks to make sure the code is working as it should. First, we check that the area is actually zero when the affinity is zero?

# %%
labels_f, labels_r = eq_params_k4()
lap = lap_k4(labels_f, labels_r)
signal = make_observable([1,2,3,4])
is_zero_at_eq(lap,signal)
# Out:
# True

# %% [markdown]
# Are the eigenvalues/eigenvectors correct? Confirm $w_i \mathcal{L}(G) = \lambda_i w_i$ and  $\mathcal{L}(G) z_i = \lambda_i z_i$. The last two lines in this cell should be the same array.

# %%
lambdas, w_i, z_i = spectrum_any(lap)

print(lambdas)
print("--------")
print(w_i)
print("--------")
print(z_i)
print("--------")
print(lambdas[0]*w_i[0,:])
print("--------")
print(w_i[0,:]@lap)
print("--------")
print(lambdas[0]*z_i[:,0])
print("--------")
print(lap@z_i[:,0])
# Out:
# [-1.23973013e+03+0.j -1.32940598e+02+0.j -2.23464432e+01+0.j
#  -2.72949789e-15+0.j]
# --------
# [[-0.85445792  0.00461643 -0.00806783  0.51943745]
#  [-0.0325437  -0.8310172   0.55482846 -0.02273103]
#  [ 0.41365159 -0.62726307 -0.51934776  0.40707655]
#  [ 0.5         0.5         0.5         0.5       ]]
# --------
# [[-0.7044149  -0.03585389  0.3723838   0.41678542]
#  [ 0.00276972 -0.66630192 -0.41095797  0.30332215]
#  [-0.00809174  0.7436622  -0.56880299  0.50706081]
#  [ 0.70973692 -0.04150638  0.60737716  0.69077849]]
# --------
# [1059.29722392-0.j   -5.72312544+0.j   10.00192953-0.j -643.96225604+0.j]
# --------
# [1059.29722392   -5.72312544   10.00192953 -643.96225604]
# --------
# [ 873.28437374-0.j   -3.43370293+0.j   10.03157604-0.j -879.88224685+0.j]
# --------
# [ 873.28437374   -3.43370293   10.03157604 -879.88224685]

# %% [markdown]
# Does $\sum_{k=1}^N L^{(k)} = I$?

# %%
check_Lk(lap)
# Out:
# True

# %% [markdown]
# Is B(G) symmetric at equilibrium?

# %%
labels_f_eq, labels_r_eq = eq_params_k4()
lap_eq = lap_k4(labels_f_eq, labels_r_eq)
lambdas, w_i, z_i = spectrum_any(lap_eq)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap_eq))
delta_u_star = np.diag(pi)
B_eq = B_matrix(lambdas, Lk_list, delta_u_star)
print(f"B symmetric at equilibrium: {check_symmetric(B_eq)}")
# Out:
# B symmetric at equilibrium: True

# %% [markdown]
# Does the numerical area agree with the analytical area?

# %%
labels_f, labels_r = eq_params_k4()
lap_eq = lap_k4(labels_f, labels_r)
aff = cycle_affinity(labels_f,labels_r)
print(f"Affinity at equilibrium: {aff:.2e}  (should be ~0)")

signal = make_observable([1,2,3,4])
tau,tau_max = define_tau_range(lap_eq, max_points=500, cap_factor=10.0, tau_cap=1000.0)
check_analytical_numerical_consistency(signal, lap_eq, tau)
print("PASS: analytical and numerical areas agree at equilibrium")

params_neq = random_parameters(num_params=8)
labels_f, labels_r = params_shuffle_k4(params_neq)
lap_neq = lap_k4(labels_f, labels_r)
aff_neq = cycle_affinity(labels_f, labels_r)
print(f"\nAffinity off equilibrium: {aff_neq:.4f}")

tau,tau_max = define_tau_range(lap_neq, max_points=500, cap_factor=10.0, tau_cap=1000.0)
a_13, a_31 = asymmetric_autocorrelation(signal, lap_neq, tau)
print(f"tau_max: {tau[-1]:.4f}")
print(f"a_13 at tau_max: {a_13[-1]:.6e}")
print(f"a_31 at tau_max: {a_31[-1]:.6e}")

tau,tau_max = define_tau_range(lap_neq, max_points=500, cap_factor=10.0, tau_cap=1000.0)
check_analytical_numerical_consistency(signal, lap_neq, tau)
print("PASS: analytical and numerical areas agree off equilibrium")
# Out:
# Affinity at equilibrium: 0.00e+00  (should be ~0)
# PASS: analytical and numerical areas agree at equilibrium
#
# Affinity off equilibrium: 16.4286
# tau_max: 16.0222
# a_13 at tau_max: 2.376556e+02
# a_31 at tau_max: 2.376564e+02
# PASS: analytical and numerical areas agree off equilibrium

# %% [markdown]
# Do the signs of the numerical and analytical signature agree?

# %%
lap_neq = lap_k4(labels_f, labels_r)
lambdas, w_i, z_i = spectrum_any(lap_neq)
r_i = normalization_factors(w_i, z_i)
Lk = projection_matrices(w_i, z_i, r_i)
B = B_matrix(lambdas, Lk, np.diag(pi_dist(lap_neq)))
s_t = np.array([signal], float); s = s_t.T
print("signed analytical:", ((s_t**3) @ (B - B.T) @ (s**1)).real.item())

tau, tau_max = define_tau_range(lap_neq, max_points=500, cap_factor=10.0, tau_cap=1000.0)
a_13, a_31 = asymmetric_autocorrelation(signal, lap_neq, tau)
print("signed numerical: ", np.trapezoid(a_13 - a_31, tau))
# Out:
# signed analytical: -23.295922900899022
# signed numerical:  -23.283945339046614

# %% [markdown]
# What is the maximum value for the area at equilibrium?

# %%
np.random.seed(0)

signal = [3,5,7,9]
alpha, beta  = 1, 3

eq_areas = []
for _ in range(100):
    labels_f, labels_r = eq_params_k4()
    lap = lap_k4(labels_f, labels_r)
    eq_areas.append(steinberg_analytical_area(signal, lap))

print(f"mean equilibrium area: {np.mean(eq_areas):.3e}")
print(f"max equilibrium area:  {np.max(eq_areas):.3e}")
# Out:
# mean equilibrium area: 3.581e-08
# max equilibrium area:  3.063e-06

# %% [markdown]
# Check that the autocorrelation functions are well behaved

# %%
plt.plot(tau, a_13, label='a_13')
plt.plot(tau, a_31, label='a_31')
plt.legend()
plt.show()

# %% [markdown]
# # Parameter set 2

# %% [markdown]
# {(1, 2): 0.008695, (1, 4): 0.3171, (2, 1): 0.002517, (2, 3): 16.022329473190215, (3, 4): 0.06513, (3, 2): 28.02, (4, 1): 0.2901, (4, 3): 0.1177}
#
#     labels_f : list of 4 floats
#         Forward rates: [k12, k23, k34, k41]
#     labels_r : list of 4 floats
#         Reverse rates: [k21, k32, k43, k14]

# %%
k12 = 0.008695
k34 = 0.06513
k41 = 0.2901

k21 = 0.002517
k32 = 28.02
k43 = 0.1177
k14 = 0.3171

k23 = (k21 * k32 * k43 * k14) / (k12 * k34 * k41)
print(k23)

labels_f = [k21, k32, k43, k14]
labels_r = [k12, k23, k34, k41]

print(labels_f)
print(labels_r)

aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
print(aff)

lap = lap_k4(labels_f,labels_r)
print(lap)

# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# 16.022329473190215
# [0.002517, 28.02, 0.1177, 0.3171]
# [0.008695, 16.022329473190215, 0.06513, 0.2901]
# 2.2204460492503128e-16
# [[-2.92617000e-01  8.69500000e-03  0.00000000e+00  3.17100000e-01]
#  [ 2.51700000e-03 -2.80286950e+01  1.60223295e+01  0.00000000e+00]
#  [ 0.00000000e+00  2.80200000e+01 -1.61400295e+01  6.51300000e-02]
#  [ 2.90100000e-01  0.00000000e+00  1.17700000e-01 -3.82230000e-01]]
# [-4.40908067e+01+0.j -6.48556283e-01+0.j -1.04208495e-01+0.j
#  -8.97532403e-16+0.j]

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

N = 2000
affinities = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)
complex_steps = []

# perturb edge k32
edge_idx = 1
perturb_edge = labels_f[edge_idx]
perturb_edge

for i in tqdm(range(0,N)):
    
    labels_f[edge_idx] = perturb_edge
    
    lap = lap_k4(labels_f, labels_r)
    
    aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
    affinities[i] = aff
    
    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0, tau_cap=1000.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)
    order = np.lexsort((lambdas.imag, lambdas.real))
    eigvals_all_r[i, :] = lambdas.real[order]
    eigvals_all_c[i, :] = lambdas.imag[order]

    zero_idx = np.argmin(np.abs(lambdas))
    assert abs(lambdas.imag[zero_idx]) < 1e-12, f"zero eigenvalue went complex at step {i}"
    if np.abs(lambdas.imag).max() > 1e-9:
        complex_steps.append(i)
    
    perturb_edge *= 1.01

lambdas, w_i, z_i = spectrum_any(lap)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap))
delta_u_star = np.diag(pi)
B_final = B_matrix(lambdas, Lk_list, delta_u_star)
print("B(G) at final step:")
print(B_final.view())
check_symmetric(B_final, rtol=1e-05, atol=1e-08)
# Out:
# 100%|███████████████████████████████████████| 2000/2000 [00:22<00:00, 89.46it/s]
# B(G) at final step:
# [[ 7.87317037e-01+0.j -1.00434998e-09+0.j -7.63704798e-01+0.j
#   -2.36122374e-02+0.j]
#  [-9.89178121e-10+0.j  2.08072028e-18+0.j  1.56439026e-09+0.j
#   -5.75212145e-10+0.j]
#  [-7.52513945e-01+0.j  1.56500997e-09+0.j  1.19002903e+00+0.j
#   -4.37515083e-01+0.j]
#  [-3.48033828e-02+0.j -5.60659215e-10+0.j -4.26323635e-01+0.j
#    4.61127018e-01+0.j]]
# False

# %%
# Steinberg curve plot
plt.plot(np.abs(affinities),numerical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities),analytical_areas,linewidth=1,color='blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 2, Figure 4B")
plt.legend()
plt.savefig("pset2_fig4b_260809.pdf")
plt.show()

# %%
complex_steps
# Out:
# []

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
plt.savefig("pset2_eigenvalues_260809.pdf", dpi=300)
plt.show()

# %% [markdown]
# # Parameter set 3

# %% [markdown]
# {(1, 2): 5.154, (1, 4): 0.2267, (2, 1): 0.01257, (2, 3): 0.0183547499419828, (3, 4): 2.321, (3, 2): 2.29, (4, 1): 0.4464, (4, 3): 15.02}
#
#     labels_f : list of 4 floats
#         Forward rates: [k12, k23, k34, k41]
#     labels_r : list of 4 floats
#         Reverse rates: [k21, k32, k43, k14]

# %%
k12 = 5.154
k34 = 2.321
k41 = 0.4464

k21 = 0.01257
k32 = 2.29
k43 = 15.02
k14 = 0.2267

k23 = (k21 * k32 * k43 * k14) / (k12 * k34 * k41)
print(k23)

labels_f = [k21, k32, k43, k14]
labels_r = [k12, k23, k34, k41]

print(labels_f)
print(labels_r)

aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
print(aff)

lap = lap_k4(labels_f,labels_r)
print(lap)

# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# 0.0183547499419828
# [0.01257, 2.29, 15.02, 0.2267]
# [5.154, 0.0183547499419828, 2.321, 0.4464]
# 0.0
# [[-4.58970000e-01  5.15400000e+00  0.00000000e+00  2.26700000e-01]
#  [ 1.25700000e-02 -7.44400000e+00  1.83547499e-02  0.00000000e+00]
#  [ 0.00000000e+00  2.29000000e+00 -1.50383547e+01  2.32100000e+00]
#  [ 4.46400000e-01  0.00000000e+00  1.50200000e+01 -2.54770000e+00]]
# [-1.73920674e+01+0.j -7.45003603e+00+0.j -6.46921322e-01+0.j
#  -1.19265596e-15+0.j]

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

N = 2000
affinities = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)
complex_steps = []

# perturb edge k34
edge_idx = 2
perturb_edge = labels_r[edge_idx]
print(perturb_edge)

for i in tqdm(range(0,N)):
    
    labels_r[edge_idx] = perturb_edge
    
    lap = lap_k4(labels_f, labels_r)
    
    aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
    affinities[i] = aff
    
    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0, tau_cap=1000.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)
    order = np.lexsort((lambdas.imag, lambdas.real))
    eigvals_all_r[i, :] = lambdas.real[order]
    eigvals_all_c[i, :] = lambdas.imag[order]

    zero_idx = np.argmin(np.abs(lambdas))
    assert abs(lambdas.imag[zero_idx]) < 1e-12, f"zero eigenvalue went complex at step {i}"
    if np.abs(lambdas.imag).max() > 1e-9:
        complex_steps.append(i)
    
    perturb_edge *= 1.01

lambdas, w_i, z_i = spectrum_any(lap)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap))
delta_u_star = np.diag(pi)
B_final = B_matrix(lambdas, Lk_list, delta_u_star)
print("B(G) at final step:")
print(B_final)
check_symmetric(B_final, rtol=1e-05, atol=1e-08)
# Out:
# 2.321
# 100%|███████████████████████████████████████| 2000/2000 [00:21<00:00, 93.73it/s]
# B(G) at final step:
# [[ 5.74261503e-02+0.j  3.48462184e-03+0.j -6.09107712e-02+0.j
#   -9.07040836e-10+0.j]
#  [-5.34637188e-05+0.j  3.23264693e-04+0.j -2.69800970e-04+0.j
#   -4.01768845e-12+0.j]
#  [-5.73726858e-02+0.j -3.80788648e-03+0.j  6.11805713e-02+0.j
#    9.11058497e-10+0.j]
#  [-8.28243999e-10+0.j -5.51159576e-11+0.j  8.83359929e-10+0.j
#    2.74658248e-17+0.j]]
# False

# %%
# Steinberg curve plot
plt.plot(np.abs(affinities),analytical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities),numerical_areas,linewidth=1, color= 'blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 3, Figure 4B")
plt.legend()
plt.savefig("pset3_fig4b_260809.pdf")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
plt.savefig("pset3_eigenvalues_260809.pdf", dpi=300)
plt.show()

# %% [markdown]
# # Parameter set 4

# %%
#np.random.seed(2)
#labels_f, labels_r = eq_params_k4()

labels_f = [0.3328, 0.09594, 0.0169, 0.890091837200075]
labels_r = [0.413, 0.001431, 1.986, 0.4092]

print(labels_f)
print(labels_r)

aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
print(aff)

lap = lap_k4(labels_f,labels_r)
print(lap)

# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# [0.3328, 0.09594, 0.0169, 0.890091837200075]
# [0.413, 0.001431, 1.986, 0.4092]
# 0.0
# [[-7.42000000e-01  4.13000000e-01  0.00000000e+00  8.90091837e-01]
#  [ 3.32800000e-01 -5.08940000e-01  1.43100000e-03  0.00000000e+00]
#  [ 0.00000000e+00  9.59400000e-02 -1.83310000e-02  1.98600000e+00]
#  [ 4.09200000e-01  0.00000000e+00  1.69000000e-02 -2.87609184e+00]]
# [-3.04890025e+00+0.j -9.05765708e-01+0.j -1.90696881e-01+0.j
#   5.00853533e-17+0.j]

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

N = 2000
affinities = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)
complex_steps = []

# perturb edge k32
edge_idx = 1
perturb_edge = labels_r[edge_idx]
perturb_edge

for i in tqdm(range(0,N)):
    
    labels_r[edge_idx] = perturb_edge
    
    lap = lap_k4(labels_f, labels_r)
    
    aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
    affinities[i] = aff

    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0, tau_cap=1000.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)
    order = np.lexsort((lambdas.imag, lambdas.real))
    eigvals_all_r[i, :] = lambdas.real[order]
    eigvals_all_c[i, :] = lambdas.imag[order]

    zero_idx = np.argmin(np.abs(lambdas))
    assert abs(lambdas.imag[zero_idx]) < 1e-12, f"zero eigenvalue went complex at step {i}"
    if np.abs(lambdas.imag).max() > 1e-9:
        complex_steps.append(i)
    
    perturb_edge *= 1.01

lambdas, w_i, z_i = spectrum_any(lap)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap))
delta_u_star = np.diag(pi)
B_final = B_matrix(lambdas, Lk_list, delta_u_star)
print("B(G) at final step:")
print(B_final)
check_symmetric(B_final, rtol=1e-05, atol=1e-08)
# Out:
# 100%|███████████████████████████████████████| 2000/2000 [00:29<00:00, 67.02it/s]
# B(G) at final step:
# [[ 2.13564342e-01+0.j -2.02477446e-01+0.j -9.29053837e-08+0.j
#   -1.10868027e-02+0.j]
#  [-2.36809941e-01+0.j  2.41923152e-01+0.j  1.11004347e-07+0.j
#   -5.11332227e-03+0.j]
#  [ 3.76706993e-08+0.j -8.85756941e-08+0.j  3.76658731e-13+0.j
#    5.09046181e-08+0.j]
#  [ 2.32455616e-02+0.j -3.94456176e-02+0.j -1.80993396e-08+0.j
#    1.62000741e-02+0.j]]
# False

# %%
plt.plot(np.abs(affinities),analytical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities),numerical_areas,linewidth=1, color= 'blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 4 (new), Figure 4B")
plt.legend()
#plt.savefig("pset4_fig4b_260809.pdf")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
#plt.savefig("pset4_eigenvalues_260809.pdf", dpi=300)
plt.show()

# %%
np.random.seed(40)
labels_f, labels_r = eq_params_k4()

print(labels_f)
print(labels_r)

aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
print(aff)

lap = lap_k4(labels_f,labels_r)
print(lap)

# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# [0.5036, 0.0666, 1.44, 0.03543533807612777]
# [0.2793, 0.002149, 53.85, 0.05295]
# 1.1102230246251565e-16
# [[-5.56550000e-01  2.79300000e-01  0.00000000e+00  3.54353381e-02]
#  [ 5.03600000e-01 -3.45900000e-01  2.14900000e-03  0.00000000e+00]
#  [ 0.00000000e+00  6.66000000e-02 -1.44214900e+00  5.38500000e+01]
#  [ 5.29500000e-02  0.00000000e+00  1.44000000e+00 -5.38854353e+01]]
# [-5.53246024e+01+0.j -8.40754660e-01+0.j -6.46773000e-02+0.j
#  -7.38084959e-16+0.j]

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

N = 2000
affinities = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)
complex_steps = []

# perturb edge k32
edge_idx = 1
perturb_edge = labels_r[edge_idx]
perturb_edge

for i in tqdm(range(0,N)):
    
    labels_r[edge_idx] = perturb_edge
    
    lap = lap_k4(labels_f, labels_r)
    
    aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
    affinities[i] = aff

    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0, tau_cap=1000.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)
    order = np.lexsort((lambdas.imag, lambdas.real))
    eigvals_all_r[i, :] = lambdas.real[order]
    eigvals_all_c[i, :] = lambdas.imag[order]

    zero_idx = np.argmin(np.abs(lambdas))
    assert abs(lambdas.imag[zero_idx]) < 1e-12, f"zero eigenvalue went complex at step {i}"
    if np.abs(lambdas.imag).max() > 1e-9:
        complex_steps.append(i)
    
    perturb_edge *= 1.01

lambdas, w_i, z_i = spectrum_any(lap)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap))
delta_u_star = np.diag(pi)
B_final = B_matrix(lambdas, Lk_list, delta_u_star)
print("B(G) at final step:")
print(B_final)
check_symmetric(B_final, rtol=1e-05, atol=1e-08)
# Out:
# 100%|███████████████████████████████████████| 2000/2000 [00:27<00:00, 72.37it/s]
# B(G) at final step:
# [[ 2.66075274e-01+0.j -2.65942318e-01+0.j -2.65057050e-08+0.j
#   -1.32929941e-04+0.j]
#  [-2.66334691e-01+0.j  2.66207694e-01+0.j  2.65320815e-08+0.j
#    1.26970430e-04+0.j]
#  [-4.03141038e-09+0.j  3.67896533e-09+0.j  7.13429174e-14+0.j
#    3.52373707e-10+0.j]
#  [ 2.59421191e-04+0.j -2.65380323e-04+0.j -2.64477955e-11+0.j
#    5.95915868e-06+0.j]]
# False

# %%
plt.plot(np.abs(affinities),analytical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities),numerical_areas,linewidth=1, color= 'blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 5, Figure 4B")
plt.legend()
plt.savefig("pset5_fig4b_260811.pdf")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
plt.savefig("pset5_eigenvalues_260809.pdf", dpi=300)
plt.show()

# %% [markdown]
# # Parameter set 1

# %%
seed = np.random.randint(0, 2**32 - 1)
print(f"seed = {seed}")
np.random.seed(seed)

labels_f, labels_r = eq_params_k4()

print(labels_f)
print(labels_r)

aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
print(aff)

lap = lap_k4(labels_f,labels_r)
print(lap)

# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# seed = 855049782
# [1.085, 272.5, 9.744, 0.09954524750854671]
# [0.3339, 880.7, 0.4242, 2.299]
# 0.0
# [[-3.38400000e+00  3.33900000e-01  0.00000000e+00  9.95452475e-02]
#  [ 1.08500000e+00 -2.72833900e+02  8.80700000e+02  0.00000000e+00]
#  [ 0.00000000e+00  2.72500000e+02 -8.90444000e+02  4.24200000e-01]
#  [ 2.29900000e+00  0.00000000e+00  9.74400000e+00 -5.23745248e-01]]
# [-1.16073700e+03+0.j -3.63778796e+00+0.j -2.81085237e+00+0.j
#  -6.94968883e-14+0.j]

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

N = 2000
affinities = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)
complex_steps = []

# perturb edge k32
edge_idx = 1
perturb_edge = labels_r[edge_idx]
perturb_edge

for i in tqdm(range(0,N)):
    
    labels_r[edge_idx] = perturb_edge
    
    lap = lap_k4(labels_f, labels_r)
    
    aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
    affinities[i] = aff

    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0, tau_cap=1000.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)
    order = np.lexsort((lambdas.imag, lambdas.real))
    eigvals_all_r[i, :] = lambdas.real[order]
    eigvals_all_c[i, :] = lambdas.imag[order]

    zero_idx = np.argmin(np.abs(lambdas))
    assert abs(lambdas.imag[zero_idx]) < 1e-12, f"zero eigenvalue went complex at step {i}"
    if np.abs(lambdas.imag).max() > 1e-9:
        complex_steps.append(i)
    
    perturb_edge *= 1.01

lambdas, w_i, z_i = spectrum_any(lap)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap))
delta_u_star = np.diag(pi)
B_final = B_matrix(lambdas, Lk_list, delta_u_star)
print("B(G) at final step:")
print(B_final)
check_symmetric(B_final, rtol=1e-05, atol=1e-08)
# Out:
# 100%|███████████████████████████████████████| 2000/2000 [00:23<00:00, 86.54it/s]
# B(G) at final step:
# [[ 1.58251739e-02+0.j  8.87141035e-03+0.j  6.31598496e-12+0.j
#   -2.46965843e-02+0.j]
#  [-4.38174608e-02+0.j  3.18232299e-01+0.j  2.26564924e-10+0.j
#   -2.74414838e-01+0.j]
#  [-3.11406314e-11+0.j  2.26027409e-10+0.j  1.62073792e-19+0.j
#   -1.94886777e-10+0.j]
#  [ 2.79922869e-02+0.j -3.27103709e-01+0.j -2.32880909e-10+0.j
#    2.99111422e-01+0.j]]
# False

# %%
plt.plot(np.abs(affinities),analytical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities),numerical_areas,linewidth=1, color= 'blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 6, Figure 4B")
plt.legend()
plt.savefig("pset6_fig4b_260811.pdf")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
plt.savefig("pset6_eigenvalues_260809.pdf", dpi=300)
plt.show()
