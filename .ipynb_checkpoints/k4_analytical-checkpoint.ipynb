# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import networkx as nx
import scipy.linalg

from steinberg import *

plt.rc("text", usetex=False)
plt.rc("font", family = "serif",size=14)
plt.rc("figure",figsize=(12,10))
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# Here, we define specific parameter sampling and Laplacian computing functions for the graph $K_4$.

# %%
def eq_params_k4():
    """
    Samples equilibrium parameter sets for a 4-state single-cycle graph
    (k12, k23, k34, k41) and (k21, k32, k43, k14), ensuring zero cycle affinity.

    Returns
    -------
    labels_f : list of 4 floats
        Forward rates: [k21, k32, k43, k14]
    labels_r : list of 4 floats
        Reverse rates: [k12, k23, k34, k41]
    """

    # Sample 7 of the 8 parameters freely
    k12 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k23 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k34 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k41 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)

    k21 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k32 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)
    k43 = round_sig(10 ** np.random.uniform(-3, 3), sig_figs=4)

    # Solve for k14 to make the cycle affinity zero
    # A(C) = log[(k12 k23 k34 k41)/(k21 k32 k43 k14)] = 0 → solve for k14
    k14 = (k12 * k23 * k34 * k41) / (k21 * k32 * k43)

    labels_f = [k21, k32, k43, k14]   # forward cycle 1->2->3->4->1
    labels_r = [k12, k23, k34, k41]   # reverse cycle 1->4->3->2->1

    return labels_f, labels_r

def params_shuffle_k4(params):
    """
    Takes randomly sampled parameters from random_parameters(num_params) and converts to labels_f and labels_r strcuture

    Returns
    -------
    labels_f : list of 4 floats
        Forward rates: [k21, k32, k43, k14]
    labels_r : list of 4 floats
        Reverse rates: [k12, k23, k34, k41]
    """
    k12 = params[0]
    k23 = params[1]
    k34 = params[2]
    k41 = params[3]

    k21 = params[4]
    k32 = params[5]
    k43 = params[6]
    k14 = params[7]

    labels_f = [k21, k32, k43, k14]   # forward cycle 1->2->3->4->1
    labels_r = [k12, k23, k34, k41]   # reverse cycle 1->4->3->2->1

    return labels_f, labels_r
    
def lap_k4(labels_f, labels_r):
    """
    Column-based Laplacian for the 4-vertex single-cycle graph K_4.

    Convention (Fig. 1C): k_ij = l(j -> i), so L[i,j] = k_ij for i != j
    and L[i,i] = -sum_k l(i -> k).

    labels_f : [k21, k32, k43, k14]   forward cycle 1->2->3->4->1
    labels_r : [k12, k23, k34, k41]   reverse cycle 1->4->3->2->1
    """
    k21, k32, k43, k14 = labels_f
    k12, k23, k34, k41 = labels_r

    return np.array([
        [-(k21 + k41),  k12,           0,            k14         ],
        [  k21,        -(k12 + k32),   k23,          0           ],
        [  0,           k32,          -(k23 + k43),  k34         ],
        [  k41,         0,             k43,         -(k14 + k34) ]], dtype=float)

# %% [markdown]
# Next, we perform a few sanity checks to make sure the code is working as it should. First, we check that the area is actually zero when the affinity is zero?

# %%
labels_f, labels_r = eq_params_k4()
lap = lap_k4(labels_f, labels_r)
signal = make_observable([1,2,3,4])
is_zero_at_eq(lap,signal)
# Out:
# True

# %% [markdown]
# Are the eigenvalues/eigenvectors correct? Confirm $w_i \mathcal{L}(G) = \lambda_i w_i$ and  $\mathcal{L}(G) z_i = \lambda_i z_i$.

# %%
lambdas, w_i, z_i = spectrum_any(lap)

# %%
lambdas
# Out:
# array([-1.03195994e+03+0.j, -2.53645579e+02+0.j, -1.29086255e+01+0.j,
#        -5.59661929e-13+0.j])

# %%
w_i
# Out:
# array([[ 4.82224095e-01, -6.12023770e-03,  3.83739760e-02,
#         -8.75185639e-01],
#        [-7.68758146e-06, -4.81645011e-02,  9.98839417e-01,
#          1.96825580e-07],
#        [-8.14230076e-04,  7.38767160e-01,  6.73959746e-01,
#         -8.24959573e-04],
#        [-5.00000000e-01, -5.00000000e-01, -5.00000000e-01,
#         -5.00000000e-01]])

# %%
z_i
# Out:
# array([[ 7.07111697e-01, -6.55181592e-02, -5.32496694e-01,
#         -8.75849094e-01],
#        [-1.47039288e-05, -6.72550671e-01,  7.91595551e-01,
#         -1.43501114e-03],
#        [ 4.87260217e-06,  7.37144566e-01,  3.81670658e-02,
#         -7.58427941e-05],
#        [-7.07101865e-01,  9.24264306e-04, -2.97265923e-01,
#         -4.82582946e-01]])

# %%
print(lambdas[0]*w_i[0,:])
# Out:
# [-497.63594585+0.j    6.3158401 -0.j  -39.60040583+0.j  903.15651582-0.j]

# %%
print(w_i[0,:]@lap)
# Out:
# [-497.63594585    6.3158401   -39.60040583  903.15651582]

# %%
print(lambdas[0]*z_i[:,0])
# Out:
# [-7.29710941e+02+0.j  1.51738655e-02-0.j -5.02833022e-03+0.j
#   7.29700795e+02-0.j]

# %%
print(lap@z_i[:,0])
# Out:
# [-7.29710941e+02  1.51738655e-02 -5.02833022e-03  7.29700795e+02]

# %% [markdown]
# Does $\sum_{k=1}^N L^{(k)} = I$?

# %%
check_Lk(lap)
# Out:
# True

# %% [markdown]
# Is B(G) symmetric at equilibrium?

# %%
labels_f_eq, labels_r_eq = eq_params_k4()
lap_eq = lap_k4(labels_f_eq, labels_r_eq)
lambdas, w_i, z_i = spectrum_any(lap_eq)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap_eq))
delta_u_star = np.diag(pi)
B_eq = B_matrix(lambdas, Lk_list, delta_u_star)
print(f"B symmetric at equilibrium: {check_symmetric(B_eq)}")
# Out:
# B symmetric at equilibrium: True

# %% [markdown]
# Does the numerical area agree with the analytical area?

# %%
labels_f, labels_r = eq_params_k4()
lap_eq = lap_k4(labels_f, labels_r)
aff = cycle_affinity(labels_f,labels_r)
print(f"Affinity at equilibrium: {aff:.2e}  (should be ~0)")

signal = make_observable([1,2,3,4])
tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
check_analytical_numerical_consistency(signal, lap_eq, tau)
print("PASS: analytical and numerical areas agree at equilibrium")

params_neq = random_parameters(num_params=8)
labels_f, labels_r = params_shuffle_k4(params_neq)
lap_neq = lap_k4(labels_f, labels_r)
aff_neq = cycle_affinity(labels_f, labels_r)
print(f"\nAffinity off equilibrium: {aff_neq:.4f}")

tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
a_13, a_31 = asymmetric_autocorrelation(signal, lap_neq, tau)
print(f"tau_max: {tau[-1]:.4f}")
print(f"a_13 at tau_max: {a_13[-1]:.6e}")
print(f"a_31 at tau_max: {a_31[-1]:.6e}")

tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
check_analytical_numerical_consistency(signal, lap_neq, tau)
print("PASS: analytical and numerical areas agree off equilibrium")
# Out:
# Affinity at equilibrium: 1.11e-16  (should be ~0)
# PASS: analytical and numerical areas agree at equilibrium
#
# Affinity off equilibrium: 19.0023
# tau_max: 0.7747
# a_13 at tau_max: 1.516744e+03
# a_31 at tau_max: 1.509779e+03
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 24
#      21 print(f"a_31 at tau_max: {a_31[-1]:.6e}")
#      23 tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
# ---> 24 check_analytical_numerical_consistency(signal, lap_neq, tau)
#      25 print("PASS: analytical and numerical areas agree off equilibrium")
#
# File ~/Desktop/All my shit/work/Gunawardena/software/steinberg-signature/steinberg.py:323, in check_analytical_numerical_consistency(signal, lap, tau, alpha, beta, rtol, atol)
#     320 numerical = numerical_area(a_13, a_31, tau)
#     322 if not np.isclose(analytical, numerical, rtol=rtol, atol=atol):
# --> 323     raise ValueError(
#     324         f"Analytical and numerical Steinberg signatures disagree:\n"
#     325         f"  analytical = {analytical:.6e}\n"
#     326         f"  numerical  = {numerical:.6e}\n"
#     327         f"  absolute error = {np.abs(analytical - numerical):.3e}"
#     328     )
#     329     return True
#
# ValueError: Analytical and numerical Steinberg signatures disagree:
#   analytical = 2.030635e+01
#   numerical  = 1.872022e+01
#   absolute error = 1.586e+00

# %% [markdown]
# Check that the autocorrelation functions are well behaved

# %%
plt.plot(tau, a_13, label='a_13')
plt.plot(tau, a_31, label='a_31')
plt.legend()
plt.show()

# %% [markdown]
# # Parameter set 2

# %% [markdown]
# {(1, 2): 0.008695, (1, 4): 0.3171, (2, 1): 0.002517, (2, 3): 16.022329473190215, (3, 4): 0.06513, (3, 2): 28.02, (4, 1): 0.2901, (4, 3): 0.1177}
#
#     labels_f : list of 4 floats
#         Forward rates: [k12, k23, k34, k41]
#     labels_r : list of 4 floats
#         Reverse rates: [k21, k32, k43, k14]

# %%
k12 = 0.008695
k34 = 0.06513
k41 = 0.2901

k21 = 0.002517
k32 = 28.02
k43 = 0.1177
k14 = 0.3171

k23 = (k21 * k32 * k43 * k14) / (k12 * k34 * k41)
print(k23)

labels_f = [k21, k32, k43, k14]
labels_r = [k12, k23, k34, k41]
aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
print(aff)
# Out:
# 16.022329473190215
# 2.2204460492503128e-16

# %%
print(labels_f)
print(labels_r)
# Out:
# [0.002517, 28.02, 0.1177, 0.3171]
# [0.008695, 16.022329473190215, 0.06513, 0.2901]

# %%
lap = lap_k4(labels_f,labels_r)
print(lap)
# Out:
# [[-2.92617000e-01  8.69500000e-03  0.00000000e+00  3.17100000e-01]
#  [ 2.51700000e-03 -2.80286950e+01  1.60223295e+01  0.00000000e+00]
#  [ 0.00000000e+00  2.80200000e+01 -1.61400295e+01  6.51300000e-02]
#  [ 2.90100000e-01  0.00000000e+00  1.17700000e-01 -3.82230000e-01]]

# %%
# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# [-4.40908067e+01+0.j -6.48556283e-01+0.j -1.04208495e-01+0.j
#  -8.97532403e-16+0.j]

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

# %%
N = 2000
affinities = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)
complex_steps = []

# perturb edge k32
edge_idx = 1
perturb_edge = labels_f[edge_idx]
perturb_edge
# Out:
# 28.02

# %%
for i in tqdm(range(0,N)):
    
    labels_f[edge_idx] = perturb_edge
    
    lap = lap_k4(labels_f, labels_r)
    
    aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
    affinities[i] = aff
    
    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)
    order = np.lexsort((lambdas.imag, lambdas.real))
    eigvals_all_r[i, :] = lambdas.real[order]
    eigvals_all_c[i, :] = lambdas.imag[order]

    zero_idx = np.argmin(np.abs(lambdas))
    assert abs(lambdas.imag[zero_idx]) < 1e-12, f"zero eigenvalue went complex at step {i}"
    if np.abs(lambdas.imag).max() > 1e-9:
        complex_steps.append(i)
    
    perturb_edge *= 1.01

lambdas, w_i, z_i = spectrum_any(lap)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap))
delta_u_star = np.diag(pi)
B_final = B_matrix(lambdas, Lk_list, delta_u_star)
print("B(G) at final step:")
print(B_final.view())
check_symmetric(B_final, rtol=1e-05, atol=1e-08)
# Out:
# 100%|███████████████████████████████████████| 2000/2000 [00:46<00:00, 42.80it/s]
# B(G) at final step:
# [[-2.21099536e-01+0.j  3.40381849e-01+0.j  4.47569032e-10+0.j
#   -1.19282313e-01+0.j]
#  [ 3.91921677e-01+0.j -6.48942661e-01+0.j -8.53296496e-10+0.j
#    2.57020985e-01+0.j]
#  [ 5.13615194e-10+0.j -8.50194054e-10+0.j -1.22120592e-18+0.j
#    3.36578861e-10+0.j]
#  [-1.70821949e-01+0.j  3.08560495e-01+0.j  4.05727046e-10+0.j
#   -1.37738546e-01+0.j]]
# False

# %%
# Steinberg curve plot
plt.plot(np.abs(affinities),numerical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities),analytical_areas,linewidth=1,color='blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 2, Figure 4B")
plt.legend()
plt.savefig("pset2_fig4b.png")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
#plt.savefig(f"eigenvalue_evolution_edge_{edge_idx}.png", dpi=300)
plt.show()

# %% [markdown]
# # Parameter set 3

# %% [markdown]
# {(1, 2): 5.154, (1, 4): 0.2267, (2, 1): 0.01257, (2, 3): 0.0183547499419828, (3, 4): 2.321, (3, 2): 2.29, (4, 1): 0.4464, (4, 3): 15.02}
#
#     labels_f : list of 4 floats
#         Forward rates: [k12, k23, k34, k41]
#     labels_r : list of 4 floats
#         Reverse rates: [k21, k32, k43, k14]

# %%
k12 = 5.154
k34 = 2.321
k41 = 0.4464

k21 = 0.01257
k32 = 2.29
k43 = 15.02
k14 = 0.2267

k23 = (k21 * k32 * k43 * k14) / (k12 * k34 * k41)

labels_f = [k12, k23, k34, k41]
labels_r = [k21, k32, k43, k14]
aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
print(aff)
# Out:
# 0.0

# %%
print(labels_f)
print(labels_r)
# Out:
# [5.154, 0.0183547499419828, 2.321, 0.4464]
# [0.01257, 2.29, 15.02, 0.2267]

# %%
lap = lap_k4(labels_f,labels_r)
print(lap)
# Out:
# [[-5.38070000e+00  1.25700000e-02  0.00000000e+00  4.46400000e-01]
#  [ 5.15400000e+00 -3.09247499e-02  2.29000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  1.83547499e-02 -4.61100000e+00  1.50200000e+01]
#  [ 2.26700000e-01  0.00000000e+00  2.32100000e+00 -1.54664000e+01]]

# %%
# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# [-1.80658798e+01+0.j -5.39012234e+00+0.j -2.03302261e+00+0.j
#   1.57605020e-15+0.j]

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

# %%
N = 2000
affinities = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)

# perturb edge k34
edge_idx = 2
perturb_edge = labels_f[edge_idx]
perturb_edge
# Out:
# 2.321

# %%
for i in tqdm(range(0,N)):
    
    labels_f[edge_idx] = perturb_edge
    
    lap = lap_k4(labels_f, labels_r)
    
    aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
    affinities[i] = aff
    
    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)
    order = np.lexsort((lambdas.imag, lambdas.real))
    eigvals_all_r[i, :] = lambdas.real[order]
    eigvals_all_c[i, :] = lambdas.imag[order]
    
    perturb_edge *= 1.01

lambdas, w_i, z_i = spectrum_any(lap)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap))
delta_u_star = np.diag(pi)
B_final = B_matrix(lambdas, Lk_list, delta_u_star)
print("B(G) at final step:")
print(B_final)
check_symmetric(B_final, rtol=1e-05, atol=1e-08)
# Out:
# 100%|███████████████████████████████████████| 2000/2000 [00:41<00:00, 48.26it/s]
# B(G) at final step:
# [[-1.04958918e-03+0.j  8.23688148e-03+0.j -1.09897421e-10+0.j
#   -7.18729219e-03+0.j]
#  [ 1.00310448e-03+0.j -9.80949433e-02+0.j  1.48458450e-09+0.j
#    9.70918374e-02+0.j]
#  [ 7.09876261e-13+0.j  1.33519866e-09+0.j -2.10637279e-17+0.j
#   -1.33590852e-09+0.j]
#  [ 4.64846947e-05+0.j  8.98580605e-02+0.j -1.37468706e-09+0.j
#   -8.99045438e-02+0.j]]
# False

# %%
# Steinberg curve plot
plt.plot(np.abs(affinities),analytical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities),numerical_areas,linewidth=1, color= 'blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 3, Figure 4B")
plt.legend()
plt.savefig("pset3_fig4b.png")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
#plt.savefig(f"eigenvalue_evolution_edge_{edge_idx}.png", dpi=300)
plt.show()

# %% [markdown]
# # Random parameter sets

# %%
np.random.seed(2)
labels_f, labels_r = eq_params_k4()
print(labels_f)
print(labels_r)
# Out:
# [0.413, 0.001431, 1.986, 0.4092]
# [0.3328, 0.09594, 0.0169, 0.890091837200075]

# %%
aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
print(aff)
# Out:
# 0.0

# %%
lap = lap_k4(labels_f,labels_r)
print(lap)
# Out:
# [[-1.30309184e+00  3.32800000e-01  0.00000000e+00  4.09200000e-01]
#  [ 4.13000000e-01 -3.34231000e-01  9.59400000e-02  0.00000000e+00]
#  [ 0.00000000e+00  1.43100000e-03 -2.08194000e+00  1.69000000e-02]
#  [ 8.90091837e-01  0.00000000e+00  1.98600000e+00 -4.26100000e-01]]

# %%
# check that eigenvalues are real and distinct (they need to stay this way)
lambdas, w_i, z_i = spectrum_any(lap)
print(lambdas)
# Out:
# [-2.11094661+0.j -1.67713959+0.j -0.35727663+0.j  0.        +0.j]

# %%
signal = [3,5,7,9]
alpha, beta  = 1, 3

N = 2000
affinities = np.empty(N, dtype=float)
analytical_areas = np.empty(N)
numerical_areas = np.empty(N)
eigvals_all_r = np.zeros((N, 4), dtype=float)
eigvals_all_c = np.zeros((N, 4), dtype=float)

# perturb edge k23
edge_idx = 1
perturb_edge = labels_f[edge_idx]
perturb_edge

for i in tqdm(range(0,N)):
    
    labels_f[edge_idx] = perturb_edge
    
    lap = lap_k4(labels_f, labels_r)
    
    aff = np.abs(np.log(np.prod(labels_f)/np.prod(labels_r)))
    affinities[i] = aff

    tau,tau_max = define_tau_range(lap, max_points=500, cap_factor=10.0)
    a_13, a_31 = asymmetric_autocorrelation(signal, lap, tau)

    numerical_areas[i] = numerical_area(a_13, a_31, tau)
    
    analytical_areas[i] = np.abs(steinberg_analytical_area(signal,lap,alpha=1,beta=3))

    lambdas, w_i, z_i = spectrum_any(lap)
    order = np.lexsort((lambdas.imag, lambdas.real))
    eigvals_all_r[i, :] = lambdas.real[order]
    eigvals_all_c[i, :] = lambdas.imag[order]
    
    perturb_edge *= 1.01

lambdas, w_i, z_i = spectrum_any(lap)
r_i = normalization_factors(w_i, z_i)
Lk_list = projection_matrices(w_i, z_i, r_i)
pi = np.array(pi_dist(lap))
delta_u_star = np.diag(pi)
B_final = B_matrix(lambdas, Lk_list, delta_u_star)
print("B(G) at final step:")
print(B_final)
check_symmetric(B_final, rtol=1e-05, atol=1e-08)
# Out:
# 100%|███████████████████████████████████████| 2000/2000 [00:34<00:00, 58.82it/s]
# B(G) at final step:
# [[-9.90004983e-02+0.j  3.70602202e-08+0.j  1.24480949e-02+0.j
#    8.65523663e-02+0.j]
#  [-6.77851000e-08+0.j -2.40223891e-13+0.j  4.76409582e-09+0.j
#    6.30212444e-08+0.j]
#  [-1.35702911e-02+0.j -6.75224993e-08+0.j -2.26800338e-02+0.j
#    3.62503925e-02+0.j]
#  [ 1.12570857e-01+0.j  3.04625193e-08+0.j  1.02319342e-02+0.j
#   -1.22802822e-01+0.j]]
# False

# %%
plt.plot(np.abs(affinities),analytical_areas,linewidth=1, color= 'black',label='analytical')
plt.plot(np.abs(affinities),numerical_areas,linewidth=1, color= 'blue',label='numerical')
plt.xlabel(r"$\tilde{A}(C)$")
plt.ylabel(r"$\mathcal{I}^{1,3}(G)$")
plt.title("Parameter set 4 (new), Figure 4B")
plt.legend()
plt.savefig("pset4_fig4b.png")
plt.show()

# %%
# Eigenvalues plots
plt.figure(figsize=(12,5))

# Real part
plt.subplot(1,2,1)
for j in range(4):
    plt.plot(affinities, eigvals_all_r[:, j], label=f"Re(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Re(λ)")
plt.title("Real Parts of Eigenvalues")
plt.legend()

# Imaginary part
plt.subplot(1,2,2)
for j in range(4):
    plt.plot(affinities, eigvals_all_c[:, j], label=f"Im(λ{j+1})")
plt.xlabel("Affinity")
plt.ylabel("Im(λ)")
plt.title("Imaginary Parts of Eigenvalues")
plt.legend()

plt.tight_layout()
#plt.savefig(f"eigenvalue_evolution_edge_{edge_idx}.png", dpi=300)
plt.show()

# %% [markdown]
# What is the maximum value for the area at equilibrium?

# %%
np.random.seed(0)
eq_areas = []
for _ in range(100):
    labels_f, labels_r = eq_params_k4()
    lap = lap_k4(labels_f, labels_r)
    eq_areas.append(steinberg_analytical_area(signal, lap))

print(f"mean equilibrium area: {np.mean(eq_areas):.3e}")
print(f"max equilibrium area:  {np.max(eq_areas):.3e}")
# Out:
# mean equilibrium area: 8.513e-09
# max equilibrium area:  5.262e-07
